# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # נבדק 1

# %%
import os
file_path = r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1002\sub-1002_task-ultimatum_run-0_raw.csv'
if os.path.exists(file_path):
    print("הקובץ נמצא!")
else:
    print("הקובץ לא נמצא!")
# Out:
# הקובץ נמצא!

# %%
csv_path = r'sourcedata\UGDG\logs\1002\sub-1002_task-ultimatum_run-0_raw.csv'
df_SUB102ULTIMATUM = pd.read_csv(csv_path)
df_SUB102ULTIMATUM.head() #קובץ של מבחן אולטימטום של נבדק ראשון, ייצוג של דאטה פריים
# Out:
#    ?TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0             1       1      2         15    8  1.5         7         1    1
# 1             2       2      3         25    3  1.5         8         0    1
# 2             3       3      2         21    5  3.0         9         7    1
# 3             4       4      1         15    1  3.0         5         3    1
# 4             5       5      1         17    5  1.5         5         8    1
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0      0  ...   6.007393    7.523706        7.523894     3  1.735912
# 1      1  ...  21.052837   22.569616       22.569810     2  1.835817
# 2      2  ...  31.094488   34.111370       34.111523     3  1.703661
# 3      3  ...  44.638702   47.655624       47.655773     2  1.520435
# 4      4  ...  54.179890   55.697296       55.697450     3  1.268358
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.259807        11.042476       3.519057  11.043097  19.047167
# 1   24.405628        26.087477       3.518021  26.087952  29.092760
# 2   35.815180        37.629337       3.518159  37.629800  42.633324
# 3   49.176210        51.172440       3.517102  51.173010  52.177235
# 4   56.965805        59.214000       3.516906  59.214474  64.218240
#
# [5 rows x 23 columns]

# %%
print(df_SUB102ULTIMATUM.columns)#ייצוג עמודות שמופיעות בקובץ של נבדק 1002
# Out:
# Index(['?TrialNumber', 'nTrial', 'Block', 'Endowment', 'ITI', 'ISI',
#        'L_Option', 'R_Option', 'ran', 'order', 'cue_Onset', 'endowment_onset',
#        'endowment_offset', 'ISI_onset', 'ISI_offset', 'decision_onset', 'resp',
#        'rt', 'resp_onset', 'decision_offset', 'trialDuration', 'ITIonset',
#        'ITIoffset'],
#       dtype='object')

# %%
df_SUB102ULTIMATUM.isnull().sum() #ערכים חסרים (אין)
# Out:
# ?TrialNumber        0
# nTrial              0
# Block               0
# Endowment           0
# ITI                 0
# ISI                 0
# L_Option            0
# R_Option            0
# ran                 0
# order               0
# cue_Onset           0
# endowment_onset     0
# endowment_offset    0
# ISI_onset           0
# ISI_offset          0
# decision_onset      0
# resp                0
# rt                  0
# resp_onset          0
# decision_offset     0
# trialDuration       0
# ITIonset            0
# ITIoffset           0
# dtype: int64

# %%
df_SUB102ULTIMATUM.drop(['ran','nTrial'], axis=1, inplace=True) #מחיקת עמודות לא רלוונטיות עקב איבוד מידע במחקר הקודם

# %%
print(df_SUB102ULTIMATUM.columns) #עמודות שנשארו אחרי הסרה
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'L_Option',
#        'R_Option', 'order', 'cue_Onset', 'endowment_onset', 'endowment_offset',
#        'ISI_onset', 'ISI_offset', 'decision_onset', 'resp', 'rt', 'resp_onset',
#        'decision_offset', 'trialDuration', 'ITIonset', 'ITIoffset'],
#       dtype='object')

# %%
df_SUB102ULTIMATUM.drop(['order','L_Option','R_Option'], axis=1, inplace=True) #הסרת עמודות שהמידע מהם נאבד

# %%
print(df_SUB102ULTIMATUM.columns) #עמודות שנשארו אחרי הסרה 
df_SUB102ULTIMATUM.head() #יצוג 5 שורות הראשונות של הנתונים
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset'],
#       dtype='object')
#    ?TrialNumber  Block  Endowment  ITI  ISI  cue_Onset  endowment_onset  \
# 0             1      2         15    8  1.5   4.990260         5.990426
# 1             2      3         25    3  1.5  20.036234        21.035868
# 2             3      2         21    5  3.0  30.077942        31.077686
# 3             4      1         15    1  3.0  43.622337        44.622250
# 4             5      1         17    5  1.5  53.163296        54.163292
#
#    endowment_offset  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0          6.007139   6.007393    7.523706        7.523894     3  1.735912
# 1         21.052696  21.052837   22.569616       22.569810     2  1.835817
# 2         31.094276  31.094488   34.111370       34.111523     3  1.703661
# 3         44.638508  44.638702   47.655624       47.655773     2  1.520435
# 4         54.179700  54.179890   55.697296       55.697450     3  1.268358
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.259807        11.042476       3.519057  11.043097  19.047167
# 1   24.405628        26.087477       3.518021  26.087952  29.092760
# 2   35.815180        37.629337       3.518159  37.629800  42.633324
# 3   49.176210        51.172440       3.517102  51.173010  52.177235
# 4   56.965805        59.214000       3.516906  59.214474  64.218240

# %%
df_SUB102ULTIMATUM.describe() #תיאור סטטיסטי של הנבדק עבור כל משימה, זמני תגובה
# Out:
#        ?TrialNumber      Block  Endowment        ITI        ISI   cue_Onset  \
# count     36.000000  36.000000  36.000000  36.000000  36.000000   36.000000
# mean      18.500000   2.000000  20.444444   2.694444   2.416667  196.644638
# std       10.535654   0.828079   3.367445   2.162267   1.149534  112.443229
# min        1.000000   1.000000  15.000000   1.000000   1.500000    4.990260
# 25%        9.750000   1.000000  17.000000   1.000000   1.500000  102.862361
# 50%       18.500000   2.000000  21.000000   2.000000   1.500000  198.232715
# 75%       27.250000   3.000000  23.000000   3.000000   3.000000  291.867512
# max       36.000000   3.000000  25.000000   8.000000   4.500000  378.997740
#
#        endowment_onset  endowment_offset   ISI_onset  ISI_offset  \
# count        36.000000         36.000000   36.000000   36.000000
# mean        197.643580        197.660228  197.660428  200.093637
# std         112.442001        112.442062  112.442069  112.651356
# min           5.990426          6.007139    6.007393    7.523706
# 25%         103.862354        103.879113  103.879295  105.395814
# 50%         199.232370        199.249060  199.249285  203.765660
# 75%         292.867597        292.884055  292.884280  296.651003
# max         379.998050        380.015170  380.015380  383.030640
#
#        decision_onset       resp         rt  resp_onset  decision_offset  \
# count       36.000000  36.000000  36.000000   36.000000        36.000000
# mean       200.093811   2.444444   1.438902  201.532713       203.610768
# std        112.651356   0.503953   0.389981  112.539791       112.651308
# min          7.523894   2.000000   0.902479    9.259807        11.042476
# 25%        105.395975   2.000000   1.147625  106.473381       108.912532
# 50%        203.765825   2.000000   1.311267  205.345985       207.283135
# 75%        296.651150   3.000000   1.711724  298.163990       300.168283
# max        383.030850   3.000000   2.335867  384.551700       386.548030
#
#        trialDuration    ITIonset   ITIoffset
# count      36.000000   36.000000   36.000000
# mean        3.517320  203.611252  206.310008
# std         0.000611  112.651298  111.932996
# min         3.516147   11.043097   19.047167
# 25%         3.517081  108.913000  111.917529
# 50%         3.517208  207.283600  208.287545
# 75%         3.517564  300.168760  301.173245
# max         3.519057  386.548520  387.552900

# %%
df_SUB102ULTIMATUM.info() #מידע בנוגע לעמודות/משתנים
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ?TrialNumber      36 non-null     int64
#  1   Block             36 non-null     int64
#  2   Endowment         36 non-null     int64
#  3   ITI               36 non-null     int64
#  4   ISI               36 non-null     float64
#  5   cue_Onset         36 non-null     float64
#  6   endowment_onset   36 non-null     float64
#  7   endowment_offset  36 non-null     float64
#  8   ISI_onset         36 non-null     float64
#  9   ISI_offset        36 non-null     float64
#  10  decision_onset    36 non-null     float64
#  11  resp              36 non-null     int64
#  12  rt                36 non-null     float64
#  13  resp_onset        36 non-null     float64
#  14  decision_offset   36 non-null     float64
#  15  trialDuration     36 non-null     float64
#  16  ITIonset          36 non-null     float64
#  17  ITIoffset         36 non-null     float64
# dtypes: float64(13), int64(5)
# memory usage: 5.2 KB

# %%
df_SUB102ULTIMATUM.loc[0:36,['endowment_onset', 'endowment_offset']] #בחירת משתנה ''תרומה'' במשחק חברתי כדי בהמשך להבין את זמן התגובה ואת ההשפעה
# Out:
#     endowment_onset  endowment_offset
# 0          5.990426          6.007139
# 1         21.035868         21.052696
# 2         31.077686         31.094276
# 3         44.622250         44.638508
# 4         54.163292         54.179700
# 5         66.206764         66.222990
# 6         76.247860         76.264366
# 7         84.287640         84.304470
# 8         96.331120         96.347755
# 9        106.372765        106.389565
# 10       116.414350        116.430890
# 11       129.958680        129.975100
# 12       140.000530        140.017490
# 13       148.040390        148.057140
# 14       156.080220        156.096770
# 15       169.124480        169.140960
# 16       178.665450        178.682070
# 17       193.711170        193.727840
# 18       204.753570        204.770280
# 19       215.796170        215.812650
# 20       226.838180        226.855200
# 21       237.880840        237.897320
# 22       247.922320        247.938660
# 23       255.978930        255.995740
# 24       272.525850        272.543100
# 25       282.067170        282.083560
# 26       290.107030        290.123400
# 27       301.149300        301.166020
# 28       309.206000        309.222700
# 29       317.246060        317.262900
# 30       330.790560        330.806980
# 31       340.831940        340.848600
# 32       350.873570        350.890320
# 33       362.416230        362.432950
# 34       370.456180        370.472930
# 35       379.998050        380.015170

# %%
df_SUB102ULTIMATUM.loc[0:36,['decision_onset', 'decision_offset']] #בחירת משתנה ''מהירות ההחלטה'' במשחק חברתי כדי בהמשך להבין את זמן התגובה ואת ההשפעה
# Out:
#     decision_onset  decision_offset
# 0         7.523894        11.042476
# 1        22.569810        26.087477
# 2        34.111523        37.629337
# 3        47.655773        51.172440
# 4        55.697450        59.214000
# 5        67.740395        71.258194
# 6        77.781364        81.298180
# 7        85.821100        89.338130
# 8        97.865270       101.381070
# 9       107.906210       111.423020
# 10      119.448170       122.965010
# 11      131.492050       135.008620
# 12      141.534060       145.049930
# 13      149.573410       153.089600
# 14      160.613700       164.131330
# 15      172.157880       175.674330
# 16      180.199920       183.716740
# 17      198.244890       201.761660
# 18      209.286760       212.804610
# 19      220.329730       223.845550
# 20      231.371750       234.888520
# 21      239.414690       242.931600
# 22      249.456730       252.973850
# 23      259.012480       262.529420
# 24      275.559500       279.076320
# 25      283.600500       287.117300
# 26      294.640400       298.157300
# 27      302.683400       306.201230
# 28      310.739380       314.256200
# 29      320.279360       323.796450
# 30      332.323670       335.840100
# 31      342.364720       345.882000
# 32      353.907320       357.424000
# 33      363.949980       367.466980
# 34      373.489100       377.006650
# 35      383.030850       386.548030

# %%
index_decision = df_SUB102ULTIMATUM.set_index(['decision_onset', 'decision_offset']) #המרת משתנים לאינדקסים 
index_decision.head()
# Out:
#                                 ?TrialNumber  Block  Endowment  ITI  ISI  \
# decision_onset decision_offset
# 7.523894       11.042476                   1      2         15    8  1.5
# 22.569810      26.087477                   2      3         25    3  1.5
# 34.111523      37.629337                   3      2         21    5  3.0
# 47.655773      51.172440                   4      1         15    1  3.0
# 55.697450      59.214000                   5      1         17    5  1.5
#
#                                 cue_Onset  endowment_onset  endowment_offset  \
# decision_onset decision_offset
# 7.523894       11.042476         4.990260         5.990426          6.007139
# 22.569810      26.087477        20.036234        21.035868         21.052696
# 34.111523      37.629337        30.077942        31.077686         31.094276
# 47.655773      51.172440        43.622337        44.622250         44.638508
# 55.697450      59.214000        53.163296        54.163292         54.179700
#
#                                 ISI_onset  ISI_offset  resp        rt  \
# decision_onset decision_offset
# 7.523894       11.042476         6.007393    7.523706     3  1.735912
# 22.569810      26.087477        21.052837   22.569616     2  1.835817
# 34.111523      37.629337        31.094488   34.111370     3  1.703661
# 47.655773      51.172440        44.638702   47.655624     2  1.520435
# 55.697450      59.214000        54.179890   55.697296     3  1.268358
#
#                                 resp_onset  trialDuration   ITIonset  \
# decision_onset decision_offset
# 7.523894       11.042476          9.259807       3.519057  11.043097
# 22.569810      26.087477         24.405628       3.518021  26.087952
# 34.111523      37.629337         35.815180       3.518159  37.629800
# 47.655773      51.172440         49.176210       3.517102  51.173010
# 55.697450      59.214000         56.965805       3.516906  59.214474
#
#                                 ITIoffset
# decision_onset decision_offset
# 7.523894       11.042476        19.047167
# 22.569810      26.087477        29.092760
# 34.111523      37.629337        42.633324
# 47.655773      51.172440        52.177235
# 55.697450      59.214000        64.218240

# %%
df_SUB102ULTIMATUM['decision_time_range']=df_SUB102ULTIMATUM['decision_offset']-df_SUB102ULTIMATUM['decision_onset']  #חישוב טווחים של זמן החלטה
df_SUB102ULTIMATUM.loc[0:36,['decision_time_range']]#ייצוג העמודה החדשה של משתנה חדש
# Out:
#     decision_time_range
# 0              3.518582
# 1              3.517667
# 2              3.517814
# 3              3.516667
# 4              3.516550
# 5              3.517799
# 6              3.516816
# 7              3.517030
# 8              3.515800
# 9              3.516810
# 10             3.516840
# 11             3.516570
# 12             3.515870
# 13             3.516190
# 14             3.517630
# 15             3.516450
# 16             3.516820
# 17             3.516770
# 18             3.517850
# 19             3.515820
# 20             3.516770
# 21             3.516910
# 22             3.517120
# 23             3.516940
# 24             3.516820
# 25             3.516800
# 26             3.516900
# 27             3.517830
# 28             3.516820
# 29             3.517090
# 30             3.516430
# 31             3.517280
# 32             3.516680
# 33             3.517000
# 34             3.517550
# 35             3.517180

# %%
index_endowment = df_SUB102ULTIMATUM.set_index(['endowment_onset', 'endowment_offset'])#המרת משתנים לאינדקסים 
index_endowment.head()
# Out:
#                                   ?TrialNumber  Block  Endowment  ITI  ISI  \
# endowment_onset endowment_offset
# 5.990426        6.007139                     1      2         15    8  1.5
# 21.035868       21.052696                    2      3         25    3  1.5
# 31.077686       31.094276                    3      2         21    5  3.0
# 44.622250       44.638508                    4      1         15    1  3.0
# 54.163292       54.179700                    5      1         17    5  1.5
#
#                                   cue_Onset  ISI_onset  ISI_offset  \
# endowment_onset endowment_offset
# 5.990426        6.007139           4.990260   6.007393    7.523706
# 21.035868       21.052696         20.036234  21.052837   22.569616
# 31.077686       31.094276         30.077942  31.094488   34.111370
# 44.622250       44.638508         43.622337  44.638702   47.655624
# 54.163292       54.179700         53.163296  54.179890   55.697296
#
#                                   decision_onset  resp        rt  resp_onset  \
# endowment_onset endowment_offset
# 5.990426        6.007139                7.523894     3  1.735912    9.259807
# 21.035868       21.052696              22.569810     2  1.835817   24.405628
# 31.077686       31.094276              34.111523     3  1.703661   35.815180
# 44.622250       44.638508              47.655773     2  1.520435   49.176210
# 54.163292       54.179700              55.697450     3  1.268358   56.965805
#
#                                   decision_offset  trialDuration   ITIonset  \
# endowment_onset endowment_offset
# 5.990426        6.007139                11.042476       3.519057  11.043097
# 21.035868       21.052696               26.087477       3.518021  26.087952
# 31.077686       31.094276               37.629337       3.518159  37.629800
# 44.622250       44.638508               51.172440       3.517102  51.173010
# 54.163292       54.179700               59.214000       3.516906  59.214474
#
#                                   ITIoffset  decision_time_range
# endowment_onset endowment_offset
# 5.990426        6.007139          19.047167             3.518582
# 21.035868       21.052696         29.092760             3.517667
# 31.077686       31.094276         42.633324             3.517814
# 44.622250       44.638508         52.177235             3.516667
# 54.163292       54.179700         64.218240             3.516550

# %%
df_SUB102ULTIMATUM['endowment_time_range']=df_SUB102ULTIMATUM['endowment_offset']-df_SUB102ULTIMATUM['endowment_onset']  #חישוב טווחים של זמן תגובה של תרומה 
df_SUB102ULTIMATUM.loc[0:36,['endowment_time_range']]#ייצוג העמודה החדשה של משתנה חדש
# Out:
#     endowment_time_range
# 0               0.016713
# 1               0.016828
# 2               0.016590
# 3               0.016258
# 4               0.016408
# 5               0.016226
# 6               0.016506
# 7               0.016830
# 8               0.016635
# 9               0.016800
# 10              0.016540
# 11              0.016420
# 12              0.016960
# 13              0.016750
# 14              0.016550
# 15              0.016480
# 16              0.016620
# 17              0.016670
# 18              0.016710
# 19              0.016480
# 20              0.017020
# 21              0.016480
# 22              0.016340
# 23              0.016810
# 24              0.017250
# 25              0.016390
# 26              0.016370
# 27              0.016720
# 28              0.016700
# 29              0.016840
# 30              0.016420
# 31              0.016660
# 32              0.016750
# 33              0.016720
# 34              0.016750
# 35              0.017120

# %%
print(df_SUB102ULTIMATUM.columns) #בדיקה שנוצרו עמודות חדשות בדאטה כללי
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset', 'decision_time_range',
#        'endowment_time_range'],
#       dtype='object')

# %%
mean_decision_time_range = df_SUB102ULTIMATUM['decision_time_range'].mean() #ממוצע של זמן ההחלטה 
print(f"ממוצע של זמן ההחלטה הוא:{mean_decision_time_range}")
mean_endowment_time_range = df_SUB102ULTIMATUM['endowment_time_range'].mean() #ממוצע של זמן מצב תרומה 
print(f"ממוצע של זמן תרומה הוא:{mean_endowment_time_range}")
mean_resp_onset = df_SUB102ULTIMATUM['resp_onset'].mean() #ממוצע של זמן תגובה  
print(f"ממוצע של זמן תגובה הוא:{mean_resp_onset}")

std_decision_time_range = df_SUB102ULTIMATUM['decision_time_range'].std() #סטיית תקן של זמן ההחלטה 
print(f"סטיית תקן של זמן ההחלטה הוא:{std_decision_time_range}")
std_endowment_time_range = df_SUB102ULTIMATUM['endowment_time_range'].std() #סטיית תקן של זמן מצב תרומה 
print(f"סטיית תקן של זמן תרומה הוא:{std_endowment_time_range}")
std_resp_onset = df_SUB102ULTIMATUM['resp_onset'].std() #סטיית תקן של זמן תגובה  
print(f"סטיית תקן של זמן תגובה הוא:{std_resp_onset}")
# Out:
# ממוצע של זמן ההחלטה הוא:3.516957352777777
# ממוצע של זמן תרומה הוא:0.01664760277777915
# ממוצע של זמן תגובה הוא:201.5327130833333
# סטיית תקן של זמן ההחלטה הוא:0.0006042924932708923
# סטיית תקן של זמן תרומה הוא:0.00023216209914542072
# סטיית תקן של זמן תגובה הוא:112.53979095157862

# %%
means = df_SUB102ULTIMATUM.mean() #גרף עבור כל העמודות של אותו הנבדק 
stds = df_SUB102ULTIMATUM.std()
df_SUB102ULTIMATUM.min().plot(kind='bar', color='pink', capsize=4)
plt.bar(means.index, means.values, yerr=stds.values, capsize=4, color='green')
plt.tight_layout()
plt.show()

# %%
df_selected = df_SUB102ULTIMATUM[['decision_time_range', 'endowment_time_range', 'resp_onset']] #בחירת 3 משתנים לחישוב קורלציה 
correlation_matrix = df_selected.corr() #חישוב קשר בין המשתנים 
print(correlation_matrix)
# Out:
#                       decision_time_range  endowment_time_range  resp_onset
# decision_time_range              1.000000              0.044526   -0.078539
# endowment_time_range             0.044526              1.000000    0.265486
# resp_onset                      -0.078539              0.265486    1.000000

# %%
import seaborn as sns 
sns.scatterplot(x='decision_time_range', y='endowment_time_range', hue='resp_onset', data=df_SUB102ULTIMATUM) #גרף קשר בין שלושת המשתנים
plt.show()

# %%
sns.scatterplot(x='decision_time_range', y='endowment_time_range', data=df_SUB102ULTIMATUM) #גרף קשר בין משתנה זמן ההחלטה וזמן תרומה המשתנים
plt.show()

# %%
sns.scatterplot(x='resp_onset', y='decision_time_range', data=df_SUB102ULTIMATUM) #גרף קשר בין זמן תגובה לזמן ההחלטה המשתנים
plt.show()

# %%
sns.scatterplot(x='resp_onset', y='endowment_time_range', data=df_SUB102ULTIMATUM) #גרף קשר בין זמן תגובה לזמן תרומה המשתנים
plt.show()

# %% [markdown]
# # נבדק 2

# %%
csv_path2 = r'sourcedata\UGDG\logs\1003\sub-1003_task-ultimatum_run-0_raw.csv'
df_SUB103ULTIMATUM = pd.read_csv(csv_path2)#קובץ של מבחן אולטימטום של נבדק שני, ייצוג של דאטה פריים 
df_SUB103ULTIMATUM.head() #רק 5 שורות ראשונות
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         15    1  1.5         0         7    1
# 1            2       2      2         23    3  1.5         1        10    1
# 2            3       3      3         19    8  1.5         0         9    1
# 3            4       4      3         19    5  3.0         6         0    1
# 4            5       5      1         15    3  1.5         5         7    1
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0      0  ...   6.012689    7.529709        7.529941     3  1.885702
# 1      1  ...  14.053198   15.570178       15.570346     3  1.418294
# 2      2  ...  24.094677   25.610819       25.611029     3  1.168816
# 3      3  ...  39.139490   42.156303       42.156525     2  1.403528
# 4      4  ...  52.684563   54.201810       54.202020     2  1.802229
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.415643        11.047641       3.518160  11.048250  12.052573
# 1   16.988640        19.087572       3.517625  19.088099  22.092854
# 2   26.779844        29.128792       3.518150  29.129309  37.134174
# 3   43.560050        45.673256       3.517115  45.673767  50.677162
# 4   56.004246        57.718246       3.516606  57.718746  60.722466
#
# [5 rows x 23 columns]

# %%
print(df_SUB103ULTIMATUM.columns)#ייצוג של עמודות/משתנים של נבדק 103
# Out:
# Index(['TrialNumber', 'nTrial', 'Block', 'Endowment', 'ITI', 'ISI', 'L_Option',
#        'R_Option', 'ran', 'order', 'cue_Onset', 'endowment_onset',
#        'endowment_offset', 'ISI_onset', 'ISI_offset', 'decision_onset', 'resp',
#        'rt', 'resp_onset', 'decision_offset', 'trialDuration', 'ITIonset',
#        'ITIoffset'],
#       dtype='object')

# %%
df_SUB103ULTIMATUM.isnull().sum().sum() #ערכים חסרים (אין)
# Out:
# np.int64(0)

# %%
df_SUB103ULTIMATUM.drop(['ran','nTrial','order','L_Option','R_Option'], axis=1, inplace=True) #מחיקת עמודות לא רלוונטיות עקב איבוד מידע במחקר הקודם

# %%
print(df_SUB103ULTIMATUM.columns)#ייצוג של עמודות/משתנים של נבדק 103 אחרי החיתוך של העמודות 
df_SUB103ULTIMATUM.head()
# Out:
# Index(['TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset'],
#       dtype='object')
#    TrialNumber  Block  Endowment  ITI  ISI  cue_Onset  endowment_onset  \
# 0            1      3         15    1  1.5   4.996274         5.996547
# 1            2      2         23    3  1.5  13.052832        14.036007
# 2            3      3         19    8  1.5  23.077616        24.077448
# 3            4      3         19    5  3.0  38.123318        39.123040
# 4            5      1         15    3  1.5  51.667995        52.667747
#
#    endowment_offset  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0          6.012495   6.012689    7.529709        7.529941     3  1.885702
# 1         14.052987  14.053198   15.570178       15.570346     3  1.418294
# 2         24.094477  24.094677   25.610819       25.611029     3  1.168816
# 3         39.139313  39.139490   42.156303       42.156525     2  1.403528
# 4         52.684360  52.684563   54.201810       54.202020     2  1.802229
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.415643        11.047641       3.518160  11.048250  12.052573
# 1   16.988640        19.087572       3.517625  19.088099  22.092854
# 2   26.779844        29.128792       3.518150  29.129309  37.134174
# 3   43.560050        45.673256       3.517115  45.673767  50.677162
# 4   56.004246        57.718246       3.516606  57.718746  60.722466

# %%
df_SUB103ULTIMATUM.describe() #תיאור סטטיסטי של הנבדק עבור כל משימה, זמני תגובה
# Out:
#        TrialNumber      Block  Endowment        ITI        ISI   cue_Onset  \
# count    36.000000  36.000000  36.000000  36.000000  36.000000   36.000000
# mean     18.500000   2.000000  19.833333   2.694444   2.416667  198.643710
# std      10.535654   0.828079   3.459975   2.162267   1.149534  112.573772
# min       1.000000   1.000000  15.000000   1.000000   1.500000    4.996274
# 25%       9.750000   1.000000  17.000000   1.000000   1.500000  107.371922
# 50%      18.500000   2.000000  20.000000   2.000000   1.500000  202.491800
# 75%      27.250000   3.000000  23.000000   3.000000   3.000000  293.004023
# max      36.000000   3.000000  25.000000   8.000000   4.500000  379.036470
#
#        endowment_onset  endowment_offset   ISI_onset  ISI_offset  \
# count        36.000000         36.000000   36.000000   36.000000
# mean        199.642611        199.659311  199.659516  202.092641
# std         112.573947        112.574008  112.574004  112.754624
# min           5.996547          6.012495    6.012689    7.529709
# 25%         108.371819        108.388784  108.389001  109.905282
# 50%         203.491495        203.508145  203.508325  207.274865
# 75%         294.003492        294.020235  294.020445  296.661720
# max         380.036400        380.053440  380.053650  383.070650
#
#        decision_onset        resp          rt  resp_onset  decision_offset  \
# count       36.000000   36.000000   36.000000   36.000000        36.000000
# mean       202.092823  113.222222  112.646141  281.315528       205.552887
# std        112.754622  317.612442  317.818946  278.141829       112.703392
# min          7.529941    2.000000    1.002082    9.415643        11.047641
# 25%        109.905442    2.000000    1.612570  111.724940       113.421323
# 50%        207.275060    3.000000    1.902897  214.008785       210.537285
# 75%        296.661870    3.000000    2.333412  317.293485       299.794465
# max        383.070830  999.000000  999.000000  999.000000       386.586980
#
#        trialDuration    ITIonset   ITIoffset
# count      36.000000   36.000000   36.000000
# mean        3.517834  205.610789  208.309503
# std         0.001531  112.754963  111.871643
# min         3.515779   11.048250   12.052573
# 25%         3.517140  113.421789  119.676040
# 50%         3.517475  210.796345  212.800270
# 75%         3.518031  300.182425  301.686712
# max         3.523819  386.587460  387.591860

# %%
df_SUB103ULTIMATUM.info() #מידע בנוגע לנתונים
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TrialNumber       36 non-null     int64
#  1   Block             36 non-null     int64
#  2   Endowment         36 non-null     int64
#  3   ITI               36 non-null     int64
#  4   ISI               36 non-null     float64
#  5   cue_Onset         36 non-null     float64
#  6   endowment_onset   36 non-null     float64
#  7   endowment_offset  36 non-null     float64
#  8   ISI_onset         36 non-null     float64
#  9   ISI_offset        36 non-null     float64
#  10  decision_onset    36 non-null     float64
#  11  resp              36 non-null     int64
#  12  rt                36 non-null     float64
#  13  resp_onset        36 non-null     float64
#  14  decision_offset   36 non-null     float64
#  15  trialDuration     36 non-null     float64
#  16  ITIonset          36 non-null     float64
#  17  ITIoffset         36 non-null     float64
# dtypes: float64(13), int64(5)
# memory usage: 5.2 KB

# %%
df_SUB103ULTIMATUM.loc[0:36,['endowment_onset', 'endowment_offset']] #בחירת משתנה ''תרומה'' במשחק חברתי כדי בהמשך להבין את זמן התגובה ואת ההשפעה
# Out:
#     endowment_onset  endowment_offset
# 0          5.996547          6.012495
# 1         14.036007         14.052987
# 2         24.077448         24.094477
# 3         39.123040         39.139313
# 4         52.667747         52.684360
# 5         62.709500         62.726322
# 6         76.253820         76.270390
# 7         84.294070         84.310180
# 8        102.341965        102.358540
# 9        110.381770        110.398865
# 10       125.427250        125.443940
# 11       137.470800        137.487850
# 12       145.510710        145.527360
# 13       158.554430        158.571300
# 14       168.597370        168.613500
# 15       178.637740        178.654250
# 16       188.178910        188.195740
# 17       197.720200        197.736700
# 18       209.262790        209.279590
# 19       220.322190        220.338870
# 20       229.863220        229.879820
# 21       241.906460        241.923320
# 22       249.946320        249.963120
# 23       259.487460        259.504460
# 24       269.528630        269.546080
# 25       280.571320        280.588440
# 26       291.614000        291.630740
# 27       301.171970        301.188720
# 28       311.213560        311.230000
# 29       321.255000        321.271420
# 30       329.294920        329.311340
# 31       339.353060        339.369960
# 32       347.393160        347.409800
# 33       362.438450        362.455540
# 34       370.495760        370.511960
# 35       380.036400        380.053440

# %%
df_SUB103ULTIMATUM.loc[0:36,['decision_onset', 'decision_offset']] #בחירת משתנה ''מהירות ההחלטה'' במשחק חברתי כדי בהמשך להבין את זמן התגובה ואת ההשפעה
# Out:
#     decision_onset  decision_offset
# 0         7.529941        11.047641
# 1        15.570346        19.087572
# 2        25.611029        29.128792
# 3        42.156525        45.673256
# 4        54.202020        57.718246
# 5        65.742640        69.259460
# 6        77.787620        81.304306
# 7        88.827040        92.344376
# 8       103.875460       107.392680
# 9       111.915436       115.430870
# 10      126.961296       130.478470
# 11      139.004180       142.521150
# 12      150.044270       153.561040
# 13      160.088290       163.604970
# 14      170.130250       173.647900
# 15      181.672130       185.188960
# 16      191.212110       194.728490
# 17      200.754040       204.272100
# 18      213.796080       216.802470
# 19      223.355420       226.872770
# 20      231.396940       234.913760
# 21      243.440250       246.956710
# 22      252.980880       256.497680
# 23      261.020780       264.538640
# 24      274.062200       277.579830
# 25      285.104580       288.620940
# 26      294.647640       297.652130
# 27      302.704560       306.221470
# 28      312.746580       316.263430
# 29      322.788640       326.305660
# 30      330.827600       333.831970
# 31      340.886350       344.403600
# 32      351.926500       355.443700
# 33      363.972260       366.975830
# 34      373.528900       377.046080
# 35      383.070830       386.586980

# %%
index_decision2 = df_SUB103ULTIMATUM.set_index(['decision_onset', 'decision_offset']) #המרת משתנים לאינדקסים 
index_decision2.head()
# Out:
#                                 TrialNumber  Block  Endowment  ITI  ISI  \
# decision_onset decision_offset
# 7.529941       11.047641                  1      3         15    1  1.5
# 15.570346      19.087572                  2      2         23    3  1.5
# 25.611029      29.128792                  3      3         19    8  1.5
# 42.156525      45.673256                  4      3         19    5  3.0
# 54.202020      57.718246                  5      1         15    3  1.5
#
#                                 cue_Onset  endowment_onset  endowment_offset  \
# decision_onset decision_offset
# 7.529941       11.047641         4.996274         5.996547          6.012495
# 15.570346      19.087572        13.052832        14.036007         14.052987
# 25.611029      29.128792        23.077616        24.077448         24.094477
# 42.156525      45.673256        38.123318        39.123040         39.139313
# 54.202020      57.718246        51.667995        52.667747         52.684360
#
#                                 ISI_onset  ISI_offset  resp        rt  \
# decision_onset decision_offset
# 7.529941       11.047641         6.012689    7.529709     3  1.885702
# 15.570346      19.087572        14.053198   15.570178     3  1.418294
# 25.611029      29.128792        24.094677   25.610819     3  1.168816
# 42.156525      45.673256        39.139490   42.156303     2  1.403528
# 54.202020      57.718246        52.684563   54.201810     2  1.802229
#
#                                 resp_onset  trialDuration   ITIonset  \
# decision_onset decision_offset
# 7.529941       11.047641          9.415643       3.518160  11.048250
# 15.570346      19.087572         16.988640       3.517625  19.088099
# 25.611029      29.128792         26.779844       3.518150  29.129309
# 42.156525      45.673256         43.560050       3.517115  45.673767
# 54.202020      57.718246         56.004246       3.516606  57.718746
#
#                                 ITIoffset
# decision_onset decision_offset
# 7.529941       11.047641        12.052573
# 15.570346      19.087572        22.092854
# 25.611029      29.128792        37.134174
# 42.156525      45.673256        50.677162
# 54.202020      57.718246        60.722466

# %%
df_SUB103ULTIMATUM['decision_time_range']=df_SUB103ULTIMATUM['decision_offset']-df_SUB103ULTIMATUM['decision_onset']  #חישוב טווחים של זמן החלטה
df_SUB103ULTIMATUM.loc[0:36,['decision_time_range']]#ייצוג העמודה החדשה של משתנה חדש
# Out:
#     decision_time_range
# 0              3.517700
# 1              3.517226
# 2              3.517763
# 3              3.516731
# 4              3.516226
# 5              3.516820
# 6              3.516686
# 7              3.517336
# 8              3.517220
# 9              3.515434
# 10             3.517174
# 11             3.516970
# 12             3.516770
# 13             3.516680
# 14             3.517650
# 15             3.516830
# 16             3.516380
# 17             3.518060
# 18             3.006390
# 19             3.517350
# 20             3.516820
# 21             3.516460
# 22             3.516800
# 23             3.517860
# 24             3.517630
# 25             3.516360
# 26             3.004490
# 27             3.516910
# 28             3.516850
# 29             3.517020
# 30             3.004370
# 31             3.517250
# 32             3.517200
# 33             3.003570
# 34             3.517180
# 35             3.516150

# %%
index_endowment2 = df_SUB103ULTIMATUM.set_index(['endowment_onset', 'endowment_offset'])#המרת משתנים לאינדקסים 
index_endowment2.head()
# Out:
#                                   TrialNumber  Block  Endowment  ITI  ISI  \
# endowment_onset endowment_offset
# 5.996547        6.012495                    1      3         15    1  1.5
# 14.036007       14.052987                   2      2         23    3  1.5
# 24.077448       24.094477                   3      3         19    8  1.5
# 39.123040       39.139313                   4      3         19    5  3.0
# 52.667747       52.684360                   5      1         15    3  1.5
#
#                                   cue_Onset  ISI_onset  ISI_offset  \
# endowment_onset endowment_offset
# 5.996547        6.012495           4.996274   6.012689    7.529709
# 14.036007       14.052987         13.052832  14.053198   15.570178
# 24.077448       24.094477         23.077616  24.094677   25.610819
# 39.123040       39.139313         38.123318  39.139490   42.156303
# 52.667747       52.684360         51.667995  52.684563   54.201810
#
#                                   decision_onset  resp        rt  resp_onset  \
# endowment_onset endowment_offset
# 5.996547        6.012495                7.529941     3  1.885702    9.415643
# 14.036007       14.052987              15.570346     3  1.418294   16.988640
# 24.077448       24.094477              25.611029     3  1.168816   26.779844
# 39.123040       39.139313              42.156525     2  1.403528   43.560050
# 52.667747       52.684360              54.202020     2  1.802229   56.004246
#
#                                   decision_offset  trialDuration   ITIonset  \
# endowment_onset endowment_offset
# 5.996547        6.012495                11.047641       3.518160  11.048250
# 14.036007       14.052987               19.087572       3.517625  19.088099
# 24.077448       24.094477               29.128792       3.518150  29.129309
# 39.123040       39.139313               45.673256       3.517115  45.673767
# 52.667747       52.684360               57.718246       3.516606  57.718746
#
#                                   ITIoffset  decision_time_range
# endowment_onset endowment_offset
# 5.996547        6.012495          12.052573             3.517700
# 14.036007       14.052987         22.092854             3.517226
# 24.077448       24.094477         37.134174             3.517763
# 39.123040       39.139313         50.677162             3.516731
# 52.667747       52.684360         60.722466             3.516226

# %%
df_SUB103ULTIMATUM['endowment_time_range']=df_SUB103ULTIMATUM['endowment_offset']-df_SUB103ULTIMATUM['endowment_onset']  #חישוב טווחים של זמן תגובה של תרומה 
df_SUB103ULTIMATUM.loc[0:36,['endowment_time_range']]#ייצוג העמודה החדשה של משתנה חדש
# Out:
#     endowment_time_range
# 0               0.015948
# 1               0.016980
# 2               0.017029
# 3               0.016273
# 4               0.016613
# 5               0.016822
# 6               0.016570
# 7               0.016110
# 8               0.016575
# 9               0.017095
# 10              0.016690
# 11              0.017050
# 12              0.016650
# 13              0.016870
# 14              0.016130
# 15              0.016510
# 16              0.016830
# 17              0.016500
# 18              0.016800
# 19              0.016680
# 20              0.016600
# 21              0.016860
# 22              0.016800
# 23              0.017000
# 24              0.017450
# 25              0.017120
# 26              0.016740
# 27              0.016750
# 28              0.016440
# 29              0.016420
# 30              0.016420
# 31              0.016900
# 32              0.016640
# 33              0.017090
# 34              0.016200
# 35              0.017040

# %%
print(df_SUB103ULTIMATUM.columns) #אחרי איחוד טבלעות
# Out:
# Index(['TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset', 'decision_time_range',
#        'endowment_time_range'],
#       dtype='object')

# %%
mean2_decision_time_range=df_SUB103ULTIMATUM['decision_time_range'].mean() #ממוצע של זמן ההחלטה 
print(f"הממוצע של זמן ההחלטה עבור נבדק 2 הוא: {mean2_decision_time_range}")
mean2_endowment_time_range=df_SUB103ULTIMATUM['endowment_time_range'].mean() #ממוצע של מצב תרומה 
print(f"הממוצע של מצב התרומה עבור נבדק 2 הוא: {mean2_endowment_time_range}")
mean2_resp_onset=df_SUB103ULTIMATUM['resp_onset'].mean() #ממוצע של תחילת זמן תגובה 
print(f"הממוצע של תחילת זמן תגובה עבור נבדק 2 הוא: {mean2_resp_onset}")

std2_decision_time_range = df_SUB103ULTIMATUM['decision_time_range'].std() #סטיית תקן של זמן ההחלטה 
print(f"סטיית תקן של זמן ההחלטה הוא:{std2_decision_time_range}")
std2_endowment_time_range = df_SUB103ULTIMATUM['endowment_time_range'].std() #סטיית תקן של זמן מצב תרומה 
print(f"סטיית תקן של זמן תרומה הוא:{std2_endowment_time_range}")
std2_resp_onset = df_SUB103ULTIMATUM['resp_onset'].std() #סטיית תקן של זמן תגובה  
print(f"סטיית תקן של זמן תגובה הוא:{std2_resp_onset}")
# Out:
# הממוצע של זמן ההחלטה עבור נבדק 2 הוא: 3.460064344444442
# הממוצע של מצב התרומה עבור נבדק 2 הוא: 0.016699869444441868
# הממוצע של תחילת זמן תגובה עבור נבדק 2 הוא: 281.31552841666667
# סטיית תקן של זמן ההחלטה הוא:0.16327876962148694
# סטיית תקן של זמן תרומה הוא:0.0003268781020691204
# סטיית תקן של זמן תגובה הוא:278.14182909437955

# %%
means = df_SUB103ULTIMATUM.mean() #גרף עבור כל העמודות של אותו הנבדק 
stds = df_SUB103ULTIMATUM.std()
plt.bar(means.index, means.values, yerr=stds.values, capsize=4, color='brown')
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
df_selected2 = df_SUB103ULTIMATUM[['decision_time_range', 'endowment_time_range', 'resp_onset']] #בחירת 3 משתנים לחישוב קורלציה 
correlation_matrix2 = df_selected2.corr() #חישוב קשר בין המשתנים 
print(correlation_matrix2)
# Out:
#                       decision_time_range  endowment_time_range  resp_onset
# decision_time_range              1.000000             -0.069601   -0.925255
# endowment_time_range            -0.069601              1.000000    0.127785
# resp_onset                      -0.925255              0.127785    1.000000

# %%
import seaborn as sns
sns.scatterplot(x='decision_time_range', y='endowment_time_range', hue='resp_onset', data=df_SUB103ULTIMATUM) #גרף קשר בין שלושת המשתנים
plt.show()

# %%
sns.scatterplot(x='decision_time_range', y='endowment_time_range', data=df_SUB103ULTIMATUM) #גרף קשר בין משתנה זמן ההחלטה וזמן תרומה המשתנים
plt.show()

# %%
sns.scatterplot(x='resp_onset', y='endowment_time_range', data=df_SUB103ULTIMATUM) #גרף קשר בין זמן תגובה לזמן תרומה המשתנים
plt.show()

# %% [markdown]
# # נבדק 3

# %%
csv_path3 = r'sourcedata\UGDG\logs\1004\sub-1004_task-ultimatum_run-0_raw.csv'
df_SUB104ULTIMATUM = pd.read_csv(csv_path3)#קובץ של מבחן אולטימטום של נבדק שלישי, ייצוג של דאטה פריים 
df_SUB104ULTIMATUM.head() #רק 5 שורות ראשונות
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         15    1  4.5         5         1  1.0
# 1            2       2      3         23    5  1.5         0         1  1.0
# 2            3       3      3         17    3  1.5         1         0  1.0
# 3            4       4      2         15    1  3.0         5         3  1.0
# 4            5       5      1         25    1  3.0         5         8  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.018691   10.534653       10.534851   2.0  1.588404
# 1    1.0  ...  17.060932   18.577522       18.577723   3.0  2.286154
# 2    2.0  ...  29.104070   30.620584       30.620783   2.0  0.518186
# 3    3.0  ...  39.145634   42.162533       42.162685   3.0  1.336417
# 4    4.0  ...  48.686710   51.703510       51.703680   3.0  2.554670
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   12.123256        14.051656       3.517272  14.052260  15.056656
# 1   20.863876        22.093616       3.516246  22.094084  27.098085
# 2   31.138968        34.137543       3.517104  34.138000  37.141550
# 3   43.499104        45.679523       3.517180  45.679980  46.683483
# 4   54.258350        55.220486       3.517172  55.220978  56.224483
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 4

# %%
csv_path4 = r'sourcedata\UGDG\logs\1006\sub-1006_task-ultimatum_run-0_raw.csv'
df_SUB106ULTIMATUM = pd.read_csv(csv_path4)#קובץ של מבחן אולטימטום של נבדק רביעי, ייצוג של דאטה פריים 
df_SUB106ULTIMATUM.head() #רק 5 שורות ראשונות
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         19    1  1.5         4         0  1.0
# 1            2       2      3         17    1  1.5         0         8  1.0
# 2            3       3      3         17    1  3.0         3         0  1.0
# 3            4       4      2         17    3  3.0         3         1  1.0
# 4            5       5      1         25    5  3.0         5         2  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.007255    7.523569        7.523790   3.0  1.553011
# 1    1.0  ...  14.047023   15.563516       15.563711   3.0  1.502525
# 2    2.0  ...  22.103888   25.119780       25.119967   2.0  1.904731
# 3    3.0  ...  31.644650   34.661472       34.661620   2.0  1.837193
# 4    4.0  ...  43.187607   46.204445       46.204590   2.0  1.636910
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.076800        11.040448       3.517105  11.041034  12.044548
# 1   17.066236        19.080585       3.517207  19.081032  20.086548
# 2   27.024696        28.637487       3.517872  28.637959  29.642435
# 3   36.498817        38.179090       3.517803  38.179543  41.183014
# 4   47.841500        49.722750       3.518503  49.723210  54.727417
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 5

# %%
csv_path5 = r'sourcedata\UGDG\logs\1007\sub-1007_task-ultimatum_run-0_raw.csv'
df_SUB107ULTIMATUM = pd.read_csv(csv_path5)#קובץ של מבחן אולטימטום של נבדק חמישי, ייצוג של דאטה פריים 
df_SUB107ULTIMATUM.head() #רק 5 שורות ראשונות
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         17    3  3.0         1         8  1.0
# 1            2       2      2         25    3  4.5        11         8  1.0
# 2            3       3      1         15    5  3.0         3         7  1.0
# 3            4       4      1         17    3  4.5         8         5  1.0
# 4            5       5      2         15    3  4.5         5         7  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.008431    9.024946        9.025148   3.0  2.689011
# 1    1.0  ...  17.551126   22.068462       22.068617   3.0  1.988203
# 2    2.0  ...  30.595295   33.612576       33.612724   2.0  1.469858
# 3    3.0  ...  44.139890   48.656483       48.656630   2.0  1.321324
# 4    4.0  ...  57.183790   61.700153       61.700302   2.0  1.088022
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.714159        12.541755       3.517063  12.542350  15.547585
# 1   24.056820        25.584288       3.516021  25.584753  28.589045
# 2   35.082580        37.130527       3.518150  37.130993  42.135273
# 3   49.977960        52.172794       3.516544  52.173306  55.176730
# 4   62.788322        65.216995       3.517077  65.217510  68.222380
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 6

# %%
csv_path6 = r'sourcedata\UGDG\logs\1009\sub-1009_task-ultimatum_run-0_raw.csv'
df_SUB109ULTIMATUM = pd.read_csv(csv_path6)#קובץ של מבחן אולטימטום של נבדק שישי, ייצוג של דאטה פריים 
df_SUB109ULTIMATUM.head() #רק 5 שורות ראשונות
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         23    3  1.5         1         0  1.0
# 1            2       2      1         21    1  1.5         4         7  1.0
# 2            3       3      2         23    5  3.0         1        10  1.0
# 3            4       4      1         25    1  1.5         5        11  1.0
# 4            5       5      2         23    8  3.0         7         4  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.015391    7.532534        7.532777   3.0  1.718961
# 1    1.0  ...  16.057283   17.574614       17.574791   3.0  1.685428
# 2    2.0  ...  24.113504   27.130491       27.130648   2.0  0.819777
# 3    3.0  ...  37.658330   39.175446       39.175620   3.0  0.951309
# 4    4.0  ...  45.698902   48.714390       48.714546   3.0  1.120641
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.251738        11.050207       3.517909  11.050829  14.056061
# 1   19.260218        21.091482       3.517051  21.091963  22.096476
# 2   27.950424        30.648464       3.518184  30.648956  35.653360
# 3   40.126930        42.692406       3.517149  42.692894  43.697750
# 4   49.835186        52.231426       3.517227  52.231888  60.236145
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 7

# %%
csv_path7 = r'sourcedata\UGDG\logs\1010\sub-1010_task-ultimatum_run-0_raw.csv'
df_SUB110ULTIMATUM = pd.read_csv(csv_path7)#קובץ של מבחן אולטימטום של נבדק שביעי, ייצוג של דאטה פריים 
df_SUB110ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB110ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1010\sub-1010_task-ultimatum_run-0_raw.csv')
#df_SUB110ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שביעי, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         17    1  1.5         0         3  1.0
# 1            2       2      2         23    1  3.0         7        10  1.0
# 2            3       3      3         15    3  3.0         0         1  1.0
# 3            4       4      1         17    8  3.0         1         8  1.0
# 4            5       5      2         15    3  1.5         7         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.011842    7.528575        7.528805   2.0  1.368316
# 1    1.0  ...  14.051548   17.067560       17.067715   2.0  2.588131
# 2    2.0  ...  23.592613   26.609129       26.609318   2.0  2.204570
# 3    3.0  ...  35.135227   38.152355       38.152527   2.0  1.871402
# 4    4.0  ...  51.682472   53.198544       53.198696   3.0  2.354441
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.897121        11.045644       3.517328  11.046282  12.050590
# 1   19.655844        20.583840       3.516488  20.584322  21.588598
# 2   28.813887        30.125902       3.517020  30.126465  33.130028
# 3   40.023930        41.669080       3.516931  41.669590  49.672960
# 4   55.553140        56.714504       3.516183  56.715004  59.718533
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 8

# %%
csv_path8 = r'sourcedata\UGDG\logs\1011\sub-1011_task-ultimatum_run-0_raw.csv'
df_SUB111ULTIMATUM = pd.read_csv(csv_path8)#קובץ של מבחן אולטימטום של נבדק שמיני, ייצוג של דאטה פריים 
df_SUB111ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB111ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1011\sub-1011_task-ultimatum_run-0_raw.csv ')
#df_SUB111ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שמיני, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         15    1  3.0         5         1  1.0
# 1            2       2      2         19    3  1.5         1         6  1.0
# 2            3       3      3         19    1  4.5         9         0  1.0
# 3            4       4      3         19    3  3.0         6         0  1.0
# 4            5       5      1         25    1  1.5        11         5  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.007903    9.024610        9.024809   3.0  1.687166
# 1    1.0  ...  15.549289   17.065485       17.065640   2.0  1.052162
# 2    2.0  ...  25.590776   30.107412       30.107613   2.0  2.038687
# 3    3.0  ...  36.633015   39.649370       39.649555   2.0  1.287451
# 4    4.0  ...  48.175785   49.692196       49.692352   3.0  1.686606
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.711974        12.542088       3.517765  12.542733  13.546956
# 1   18.117802        20.583485       3.518239  20.584002  23.587622
# 2   32.146297        33.624405       3.517164  33.624897  34.628400
# 3   40.937004        43.166348       3.517138  43.166810  46.170345
# 4   51.378956        53.209145       3.517144  53.209610  54.214070
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 9

# %%
csv_path9 = r'sourcedata\UGDG\logs\1012\sub-1012_task-ultimatum_run-0_raw.csv'
df_SUB112ULTIMATUM = pd.read_csv(csv_path9)#קובץ של מבחן אולטימטום של נבדק תשיעי, ייצוג של דאטה פריים 
df_SUB112ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB112ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1012\sub-1012_task-ultimatum_run-0_raw.csv')
#df_SUB112ULTIMATUM #קובץ של מבחן אולטימטום של נבדק תשיעי, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         25    8  1.5         5         2  1.0
# 1            2       2      3         19    3  3.0         1         0  1.0
# 2            3       3      2         23    5  4.5         4        10  1.0
# 3            4       4      3         21    3  1.5         7         0  1.0
# 4            5       5      3         19    5  3.0         0         9  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.015924    7.532322        7.532522   3.0  1.602787
# 1    1.0  ...  21.061872   24.078453       24.078648   3.0  2.337742
# 2    2.0  ...  32.604645   37.121178       37.121338   2.0  1.404458
# 3    3.0  ...  47.650494   49.167305       49.167492   2.0  2.736563
# 4    4.0  ...  57.691880   60.708150       60.708350   3.0  2.521685
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.135309        11.050431       3.518403  11.051079  19.055449
# 1   26.416390        27.595716       3.517416  27.596182  30.599575
# 2   38.525795        40.638410       3.517421  40.638878  45.642326
# 3   51.904057        52.684055       3.516918  52.684530  55.688282
# 4   63.230034        64.225020       3.517040  64.225510  69.229240
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 10

# %%
csv_path10 = r'sourcedata\UGDG\logs\1013\sub-1013_task-ultimatum_run-0_raw.csv'
df_SUB113ULTIMATUM = pd.read_csv(csv_path10)#קובץ של מבחן אולטימטום של נבדק עשירי, ייצוג של דאטה פריים 
df_SUB113ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB113ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1013\sub-1013_task-ultimatum_run-0_raw.csv')
#df_SUB113ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשירי, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         23    8  4.5         0        10  1.0
# 1            2       2      1         17    1  1.5         8         5  1.0
# 2            3       3      1         25    3  1.5         5         8  1.0
# 3            4       4      1         17    5  1.5         8         3  1.0
# 4            5       5      3         23    1  1.5         0         7  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.010884   10.527523       10.527749   3.0  1.955311
# 1    1.0  ...  24.059261   25.576500       25.576654   3.0  1.768566
# 2    2.0  ...  32.115948   33.632904       33.633053   3.0  1.435407
# 3    3.0  ...  42.157340   43.673603       43.673750   2.0  1.469157
# 4    4.0  ...  54.200710   55.717610       55.717796   3.0  2.719866
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   12.483060        14.044636       3.517335  14.045372  22.049610
# 1   27.345219        29.094643       3.518329  29.095097  30.099619
# 2   35.068462        37.149612       3.516895  37.150063  40.153564
# 3   45.142910        47.191020       3.517608  47.191475  52.196070
# 4   58.437660        59.235560       3.518114  59.236027  60.239740
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 11

# %%
csv_path11 = r'sourcedata\UGDG\logs\1015\sub-1015_task-ultimatum_run-0_raw.csv'
df_SUB115ULTIMATUM = pd.read_csv(csv_path11)#קובץ של מבחן אולטימטום של נבדק אחד עשרה, ייצוג של דאטה פריים 
df_SUB115ULTIMATUM.head() #רק 5 שורות ראשונות 
#df_SUB115ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1015\sub-1015_task-ultimatum_run-0_raw.csv')
#df_SUB115ULTIMATUM #קובץ של מבחן אולטימטום של נבדק אחד עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         21    1  1.5         0         4  1.0
# 1            2       2      1         23    1  1.5         4        10  1.0
# 2            3       3      2         17    5  1.5         3         1  1.0
# 3            4       4      2         25    1  3.0        11         8  1.0
# 4            5       5      2         23    1  1.5         7        10  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.014288    7.531403        7.531635   3.0  1.218481
# 1    1.0  ...  14.070815   15.587675       15.587832   2.0  0.918256
# 2    2.0  ...  22.110777   23.627209       23.627360   2.0  2.120899
# 3    3.0  ...  34.154034   37.169860       37.170017   3.0  0.838076
# 4    4.0  ...  43.695330   45.211580       45.211727   2.0  1.102636
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.750115        11.048265       3.517077  11.048856  12.053687
# 1   16.506088        19.105642       3.518147  19.106092  20.109589
# 2   25.748259        27.144625       3.517607  27.145082  32.149357
# 3   38.008090        40.685610       3.515928  40.686058  41.689533
# 4   46.314365        48.728590       3.517199  48.729040  49.733692
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 12

# %%
csv_path12 = r'sourcedata\UGDG\logs\1016\sub-1016_task-ultimatum_run-0_raw.csv'
df_SUB116ULTIMATUM = pd.read_csv(csv_path12)#קובץ של מבחן אולטימטום של נבדק שתיים עשרה, ייצוג של דאטה פריים 
df_SUB116ULTIMATUM.head() #רק 5 שורות ראשונות 
#df_SUB116ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1016\sub-1016_task-ultimatum_run-0_raw.csv')
#df_SUB116ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שתיים עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         23    1  4.5         7        10  1.0
# 1            2       2      3         25    1  1.5         0        11  1.0
# 2            3       3      2         17    1  3.0         3         5  1.0
# 3            4       4      3         15    5  3.0         5         0  1.0
# 4            5       5      3         19    1  1.5         0         1  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.015441   10.531822       10.532023   2.0  1.188381
# 1    1.0  ...  17.057545   18.574003       18.574190   3.0  1.269125
# 2    2.0  ...  25.097713   28.114416       28.114570   2.0  0.970187
# 3    3.0  ...  34.638450   37.655320       37.655506   2.0  1.436865
# 4    4.0  ...  48.183067   49.700325       49.700516   3.0  1.135069
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.720405        14.048485       3.516908  14.049070  15.053866
# 1   19.843315        22.091003       3.517159  22.091465  23.096437
# 2   29.084759        31.630405       3.516190  31.630880  32.635406
# 3   39.092373        41.172764       3.517623  41.173252  46.177567
# 4   50.835583        53.217310       3.517148  53.217780  54.222300
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 13

# %%
csv_path13 = r'sourcedata\UGDG\logs\1019\sub-1019_task-ultimatum_run-0_raw.csv'
df_SUB119ULTIMATUM = pd.read_csv(csv_path13)#קובץ של מבחן אולטימטום של נבדק שלוש עשרה, ייצוג של דאטה פריים 
df_SUB119ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB119ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1016\sub-1016_task-ultimatum_run-0_raw.csv')
#df_SUB119ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלוש עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         17    8  3.0         3         0  1.0
# 1            2       2      1         19    1  4.5         4         1  1.0
# 2            3       3      2         23    1  1.5         4         1  1.0
# 3            4       4      3         23    5  3.0         0         7  1.0
# 4            5       5      3         17    1  3.0         3         0  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.020799    9.037707        9.037951   2.0  1.119285
# 1    1.0  ...  22.567240   27.083940       27.084093   3.0  1.021063
# 2    2.0  ...  33.610237   35.125620       35.125770   2.0  0.886834
# 3    3.0  ...  41.650467   44.666570       44.666750   2.0  1.270212
# 4    4.0  ...  55.194286   58.211575       58.211765   3.0  1.620084
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.157237        12.554685       3.517266  12.555376  20.558691
# 1   28.105156        30.600931       3.517217  30.601430  31.606241
# 2   36.012604        38.643364       3.517926  38.643810  39.648620
# 3   45.936962        48.183617       3.517216  48.184082  53.187590
# 4   59.831850        61.728580       3.517148  61.729027  62.734325
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 14

# %%
csv_path14 = r'sourcedata\UGDG\logs\1021\sub-1021_task-ultimatum_run-0_raw.csv'
df_SUB1021ULTIMATUM = pd.read_csv(csv_path14)#קובץ של מבחן אולטימטום של נבדק ארבע עשרה, ייצוג של דאטה פריים 
df_SUB1021ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1021ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1021\sub-1021_task-ultimatum_run-0_raw.csv ')
#df_SUB1021ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבע עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         23    3  3.0         0         1  1.0
# 1            2       2      2         15    1  1.5         5         1  1.0
# 2            3       3      2         25    1  3.0         8        11  1.0
# 3            4       4      1         21    5  1.5         4         7  1.0
# 4            5       5      2         17    1  1.5         5         1  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.017899    9.034227        9.034451   2.0  2.070962
# 1    1.0  ...  17.560474   19.077930       19.078081   2.0  1.635340
# 2    2.0  ...  25.600576   28.616491       28.616638   3.0  1.404347
# 3    3.0  ...  35.141470   36.658455       36.658610   3.0  1.285725
# 4    4.0  ...  47.185070   48.701084       48.701233   2.0  1.152582
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.105413        12.552520       3.518532  12.553124  15.557142
# 1   20.713423        22.594435       3.516700  22.594894  23.599571
# 2   30.020985        32.133510       3.517269  32.134018  33.137516
# 3   37.944336        40.175842       3.517582  40.176315  45.181200
# 4   49.853817        52.218372       3.517477  52.218826  53.223125
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 15

# %%
csv_path15 = r'sourcedata\UGDG\logs\1240\sub-1240_task-ultimatum_run-0_raw.csv'
df_SUB1240ULTIMATUM = pd.read_csv(csv_path15)#קובץ של מבחן אולטימטום של נבדק חמש עשרה, ייצוג של דאטה פריים 
df_SUB1240ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB1240ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1240\sub-1240_task-ultimatum_run-0_raw.csv')
#df_SUB1240ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמש עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  ISI  ITI  L_Option  Endowment  R_Option  nTrial  Block  ran  \
# 0            1  1.5    1         4         23         0       1      3  1.0
# 1            2  4.5    1        11         25         8       2      2  1.0
# 2            3  3.0    1         9         21         1       3      2  1.0
# 3            4  1.5    1         0         15         5       4      3  1.0
# 4            5  1.5    5         0         17         8       5      3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp       rt  \
# 0    0.0  ...    6.00661     7.52398         7.52421   2.0  1.13249
# 1    1.0  ...   14.05670    18.57360        18.57380   3.0  1.99996
# 2    2.0  ...   25.10670    28.12310        28.12330   2.0  1.53348
# 3    3.0  ...   34.65660    36.17360        36.17380   3.0  1.64960
# 4    4.0  ...   42.70660    44.22310        44.22330   2.0  1.68339
#
#    resp_onset  decision_offset  trialDuration  ITIonset  ITIoffset
# 0      8.6567          11.0412        3.51754   11.0419    12.0466
# 1     20.5737          22.0895        3.51612   22.0900    23.0936
# 2     29.6567          31.6390        3.51606   31.6395    32.6436
# 3     37.8234          39.6893        3.51586   39.6898    40.6939
# 4     45.9067          47.7396        3.51666   47.7401    52.7443
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 16

# %%
csv_path16 = r'sourcedata\UGDG\logs\1242\sub-1242_task-ultimatum_run-0_raw.csv'
df_SUB1242ULTIMATUM = pd.read_csv(csv_path16)#קובץ של מבחן אולטימטום של נבדק שש עשרה, ייצוג של דאטה פריים 
df_SUB1242ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB1242ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1242\sub-1242_task-ultimatum_run-0_raw.csv')
#df_SUB1242ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שש עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         23    3  4.5         7         4  1.0
# 1            2       2      1         25    1  1.5         2         8  1.0
# 2            3       3      3         23    3  1.5         0         4  1.0
# 3            4       4      3         23    1  3.0         0         7  1.0
# 4            5       5      2         21    1  3.0         9         7  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.006552   10.522896       10.523086   2.0  1.149979
# 1    1.0  ...  19.056330   20.572826       20.572980   3.0  1.683124
# 2    2.0  ...  27.106178   28.623503       28.623692   2.0  1.999491
# 3    3.0  ...  37.156220   40.173200       40.173420   3.0  1.966452
# 4    4.0  ...  46.706280   49.722600       49.722750   3.0  1.450263
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.673064        14.040417       3.517791  14.041020  17.045534
# 1   22.256104        24.089897       3.517264  24.090363  25.094170
# 2   30.623182        32.140263       3.516909  32.140717  35.144930
# 3   42.139870        43.689915       3.516847  43.690388  44.694140
# 4   51.173010        53.239166       3.516761  53.239628  54.243420
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 17

# %%
csv_path17 = r'sourcedata\UGDG\logs\1243\sub-1243_task-ultimatum_run-0_raw.csv'
df_SUB1243ULTIMATUM = pd.read_csv(csv_path17)#קובץ של מבחן אולטימטום של נבדק שבע עשרה, ייצוג של דאטה פריים 
df_SUB1243ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1243ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1243\sub-1243_task-ultimatum_run-0_raw.csv')
#df_SUB1243ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שבע עשרה, ייצוג של דאטה פריים
# Out:
#   TrialNumber nTrial Block Endowment ITI  ISI L_Option R_Option  ran order  \
# 0           1      1     1        15   5  1.5        3        5  1.0   0.0
# 1           2      2     1        15   1    3        1        7  1.0   1.0
# 2           3      3     2        23   3    3        4        1  1.0   2.0
# 3           4      4     1        15   3  1.5        7        1  1.0   3.0
# 4           5      5     1        25   1  4.5        5       11  1.0   4.0
#
#    ...  ISI_onset ISI_offset decision_onset resp          rt resp_onset  \
# 0  ...   6.014707  7.5312786       7.531475  3.0    1.383737   8.915213
# 1  ...  18.064821  21.081224      21.081396  3.0   0.8336499  21.915047
# 2  ...  27.614882  30.631199      30.631351  2.0   0.8668344  31.498186
# 3  ...   39.16462   40.68116      40.681316  2.0  0.83360547  41.514923
# 4  ...  49.214664    53.7311      53.731255  3.0   0.9835866   54.71484
#
#   decision_offset trialDuration   ITIonset  ITIoffset
# 0       11.048089      3.517384  11.049014  16.054472
# 1       24.598139      3.517412  24.598938  25.603228
# 2        34.14843      3.517746  34.149227    37.1544
# 3       44.198196     3.5175395  44.198986  47.203335
# 4        57.24806     3.5174644  57.248848   58.25313
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 18

# %%
csv_path18 = r'sourcedata\UGDG\logs\1244\sub-1244_task-ultimatum_run-0_raw.csv'
df_SUB1244ULTIMATUM = pd.read_csv(csv_path18)#קובץ של מבחן אולטימטום של נבדק שמונה עשרה, ייצוג של דאטה פריים 
df_SUB1244ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1244ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1244\sub-1244_task-ultimatum_run-0_raw.csv')
#df_SUB1244ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שמונה עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         15    8  1.5         3         7  1.0
# 1            2       2      1         17    3  3.0         3         5  1.0
# 2            3       3      2         23    1  3.0        10         7  1.0
# 3            4       4      1         17    1  1.5         5         1  1.0
# 4            5       5      2         19    1  1.5         9         1  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.006205    7.522453        7.522648   2.0  1.050528
# 1    1.0  ...  21.056280   24.073460       24.073620   3.0  1.616013
# 2    2.0  ...  32.606236   35.622470       35.622627   3.0  1.933761
# 3    3.0  ...  42.156440   43.673480       43.673640   2.0  0.982797
# 4    4.0  ...  50.206240   51.722466       51.722630   3.0  0.866883
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.573175        11.039255       3.517386  11.040197  19.044468
# 1   25.689632        27.589476       3.516544  27.590319  30.594482
# 2   37.556390        39.139324       3.517365  39.140125  40.144180
# 3   44.656437        47.190740       3.517775  47.191555  48.196045
# 4   52.589516        55.240010       3.518056  55.240826  56.245445
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 19

# %%
csv_path19 = r'sourcedata\UGDG\logs\1245\sub-1245_task-ultimatum_run-0_raw.csv'
df_SUB1245ULTIMATUM = pd.read_csv(csv_path19)#קובץ של מבחן אולטימטום של נבדק תשע עשרה, ייצוג של דאטה פריים 
df_SUB1245ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1245ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1245\sub-1245_task-ultimatum_run-0_raw.csv')
#df_SUB1245ULTIMATUM #קובץ של מבחן אולטימטום של נבדק תשע עשרה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         25    3  3.0         2         0  1.0
# 1            2       2      3         25    1  3.0         8         0  1.0
# 2            3       3      2         15    1  1.5         3         5  1.0
# 3            4       4      2         15    5  1.5         1         3  1.0
# 4            5       5      2         25    8  3.0         8         5  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset   resp          rt  \
# 0    0.0  ...   6.019621    9.035573        9.035814    3.0    1.667512
# 1    1.0  ...  17.569723   20.587204       20.587389    2.0    1.249162
# 2    2.0  ...  27.119960   28.637062       28.637209    3.0    1.815749
# 3    3.0  ...  35.169790   36.686740       36.686890    3.0    2.083011
# 4    4.0  ...  47.219906   50.237040       50.237190  999.0  999.000000
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.703326        12.552400       3.517029  12.552984  15.557358
# 1   21.836550        24.104000       3.516947  24.104454  25.109446
# 2   30.452960        32.154686       3.517806  32.155132  33.159725
# 3   38.769900        40.203667       3.517111  40.204120  45.208366
# 4  999.000000        53.253376       3.532583  53.769978  61.774060
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 20

# %%
csv_path20 = r'sourcedata\UGDG\logs\1247\sub-1247_task-ultimatum_run-0_raw.csv'
df_SUB1247ULTIMATUM = pd.read_csv(csv_path20)#קובץ של מבחן אולטימטום של נבדק עשרים, ייצוג של דאטה פריים 
df_SUB1247ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1247ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1247\sub-1247_task-ultimatum_run-0_raw.csv')
#df_SUB1247ULTIMATUM #קובץ של מבחן אולטימטום של נבדק  עשרים, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         19    3  3.0         1         6  1.0
# 1            2       2      1         23    3  1.5        10         1  1.0
# 2            3       3      1         19    1  1.5         6         9  1.0
# 3            4       4      2         15    1  3.0         3         5  1.0
# 4            5       5      1         25    1  1.5         5         2  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.006817    9.023017        9.023213   2.0  1.066752
# 1    1.0  ...  17.556520   19.072912       19.073078   2.0  1.033490
# 2    2.0  ...  27.606602   29.123108       29.123274   2.0  1.466833
# 3    3.0  ...  35.656677   38.672974       38.673126   2.0  0.866844
# 4    4.0  ...  45.206512   46.722992       46.723152   2.0  0.916776
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.089966        12.540322       3.517924  12.541336  15.545616
# 1   20.106567        22.590038       3.517650  22.590866  25.595594
# 2   30.590105        32.640537       3.517941  32.641350  33.646618
# 3   39.539970        42.190643       3.518180  42.191433  43.195595
# 4   47.639927        50.240795       3.518307  50.241610  51.246136
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 21

# %%
csv_path21 = r'sourcedata\UGDG\logs\1248\sub-1248_task-ultimatum_run-0_raw.csv'
df_SUB1248ULTIMATUM = pd.read_csv(csv_path21)#קובץ של מבחן אולטימטום של נבדק עשרים ואחד, ייצוג של דאטה פריים 
df_SUB1248ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1248ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1248\sub-1248_task-ultimatum_run-0_raw.csv')
#df_SUB1248ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים ואחד, ייצוג של דאטה פריים
# Out:
#    TrialNumber  ISI  ITI  L_Option  Endowment  R_Option  nTrial  Block  ran  \
# 0            1  1.5    1        11         25         2       1      1  1.0
# 1            2  1.5    1         1         21         7       2      2  1.0
# 2            3  3.0    1         1         23         0       3      3  1.0
# 3            4  1.5    3         0         15         5       4      3  1.0
# 4            5  3.0    1         7         21         0       5      3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...    6.01526     7.53143         7.53162   3.0  0.916549
# 1    1.0  ...   14.06500    15.58160        15.58180   3.0  1.583590
# 2    2.0  ...   22.11520    25.13220        25.13240   2.0  1.882820
# 3    3.0  ...   31.66500    33.18130        33.18150   3.0  1.200290
# 4    4.0  ...   41.71520    44.73120        44.73140   2.0  2.366780
#
#    resp_onset  decision_offset  trialDuration  ITIonset  ITIoffset
# 0     8.44817          11.0478        3.51665   11.0484    12.0536
# 1    17.16540          19.0974        3.51597   19.0979    20.1021
# 2    27.01520          28.6481        3.51612   28.6486    29.6530
# 3    34.38180          36.6969        3.51579   36.6974    39.7017
# 4    47.09820          48.2477        3.51662   48.2482    49.2535
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 22

# %%
csv_path22 = r'sourcedata\UGDG\logs\1249\sub-1249_task-ultimatum_run-0_practice_raw.csv'
df_SUB1249ULTIMATUM = pd.read_csv(csv_path22)#קובץ של מבחן אולטימטום של נבדק עשרים ושתיים, ייצוג של דאטה פריים 
df_SUB1249ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB1249ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1249\sub-1249_task-ultimatum_run-0_practice_raw.csv')
#df_SUB1249ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים ושתיים, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         25    1  1.5         0         5  1.0
# 1            2       2      3         15    1  1.5         0         1  1.0
# 2            3       3      1         19    1  3.0         1         9  1.0
# 3            4       4      3         15    1  1.5         0         3  1.0
# 4            5       5      2         23    1  1.5        10         4  1.0
#
#   order  ...  ISI_onset ISI_offset decision_onset   resp        rt resp_onset  \
# 0   0.0  ...  6.0257816  7.5312433        7.53143  999.0     999.0      999.0
# 1   1.0  ...  14.071625  15.577129      15.577281  999.0     999.0      999.0
# 2   2.0  ...   22.12811  25.133474      25.133598  999.0     999.0      999.0
# 3   3.0  ...   31.68348  33.188797       33.18895    2.0  1.811454  35.000404
# 4   4.0  ...  39.727467  41.233128      41.233253    2.0  2.090454  43.323708
#
#   decision_offset trialDuration   ITIonset  ITIoffset
# 0       10.532917     3.5187285  11.050375  12.055693
# 1       18.588844     3.5285769  19.106022   20.11136
# 2       28.145763     3.5289562  28.662712  29.668137
# 3        36.70614     3.5177884  36.706867  37.712086
# 4       44.750504      3.517816    44.7512  45.756496
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 23

# %%
csv_path23 = r'sourcedata\UGDG\logs\1251\sub-1251_task-ultimatum_run-0_raw.csv'
df_SUB1251ULTIMATUM = pd.read_csv(csv_path23)#קובץ של מבחן אולטימטום של נבדק עשרים ושלוש, ייצוג של דאטה פריים 
df_SUB1251ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1251ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1251\sub-1251_task-ultimatum_run-0_raw.csv')
#df_SUB1251ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים ושלוש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         25    5  3.0         5        11  1.0
# 1            2       2      3         19    5  3.0         6         0  1.0
# 2            3       3      2         15    8  1.5         7         1  1.0
# 3            4       4      1         23    1  3.0         1         7  1.0
# 4            5       5      3         25    8  1.5         0         8  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.008582    9.025430        9.025638   2.0  1.199730
# 1    1.0  ...  19.558430   22.573970       22.574167   2.0  2.151088
# 2    2.0  ...  33.108612   34.624912       34.625076   3.0  1.366618
# 3    3.0  ...  48.158344   51.175320       51.175490   3.0  1.182881
# 4    4.0  ...  57.708390   59.225147       59.225346   3.0  1.549720
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.225368        12.543423       3.518602  12.544412  17.549810
# 1   24.725254        26.091387       3.517930  26.092264  31.097160
# 2   35.991695        38.142050       3.517684  38.142944  46.147606
# 3   52.358370        54.693290       3.518522  54.694150  55.698690
# 4   60.775066        62.742210       3.517537  62.743020  70.747150
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 24

# %%
csv_path24 = r'sourcedata\UGDG\logs\1253\sub-1253_task-ultimatum_run-0_raw.csv'
df_SUB1253ULTIMATUM = pd.read_csv(csv_path24)#קובץ של מבחן אולטימטום של נבדק עשרים וארבע, ייצוג של דאטה פריים 
df_SUB1253ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB1253ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1253\sub-1253_task-ultimatum_run-0_raw.csv')
#df_SUB1253ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים וארבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         15    1  1.5         1         7  1.0
# 1            2       2      2         23    1  1.5         4         1  1.0
# 2            3       3      3         19    1  4.5         6         0  1.0
# 3            4       4      1         19    1  4.5         1         6  1.0
# 4            5       5      2         17    1  1.5         5         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset   resp          rt  \
# 0    0.0  ...   6.013515    7.530004        7.530193    2.0    1.999842
# 1    1.0  ...  14.063402   15.579649       15.579807  999.0  999.000000
# 2    2.0  ...  22.129930   26.646640       26.646828  999.0  999.000000
# 3    3.0  ...  33.196680   37.713320       37.713474    2.0    1.599895
# 4    4.0  ...  44.246777   45.763080       45.763230    3.0    1.550252
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.530035        11.048310       3.518883  11.049235  12.053701
# 1  999.000000        18.596565       3.533780  19.113804  20.118116
# 2  999.000000        29.663221       3.533462  30.180471  31.184977
# 3   39.313370        41.230736       3.517919  41.231525  42.235973
# 4   47.313484        49.279343       3.516767  49.280150  50.284680
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 25

# %%
csv_path25 = r'sourcedata\UGDG\logs\1255\sub-1255_task-ultimatum_run-0_practice_raw.csv'
df_SUB1255ULTIMATUM = pd.read_csv(csv_path25)#קובץ של מבחן אולטימטום של נבדק עשרים וחמש, ייצוג של דאטה פריים 
df_SUB1255ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1255ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1255\sub-1255_task-ultimatum_run-0_practice_raw.csv')
#df_SUB1255ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים וחמש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         17    1  1.5         8         3  1.0
# 1            2       2      3         23    5  1.5         1         0  1.0
# 2            3       3      1         17    3  1.5         3         5  1.0
# 3            4       4      1         23    3  1.5         1         4  1.0
# 4            5       5      2         23    1  3.0         7         1  1.0
#
#   order  ...  ISI_onset ISI_offset decision_onset   resp         rt  \
# 0   0.0  ...   6.025029   7.530507      7.5306644  999.0      999.0
# 1   1.0  ...   14.08595  15.591218      15.591372    2.0  1.4601173
# 2   2.0  ...  26.130758  27.636257      27.636381  999.0      999.0
# 3   3.0  ...  36.182487  37.688034      37.688164    2.0  1.5119597
# 4   4.0  ...  46.225594   49.23198       49.23212    3.0  1.7098187
#
#   resp_onset decision_offset trialDuration    ITIonset  ITIoffset
# 0      999.0       10.546525     3.5327573  11.0636425  12.068792
# 1  17.051489       19.107807     3.5170105   19.108511  24.113981
# 2      999.0       30.644201     3.5248291   31.161396  34.166653
# 3  39.200123       41.205853      3.518252   41.206543  44.211967
# 4   50.94194        52.74945     3.5178945    52.75014   53.75558
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 26

# %%
csv_path26 = r'sourcedata\UGDG\logs\1276\sub-1276_task-ultimatum_run-0_raw.csv'
df_SUB1276ULTIMATUM = pd.read_csv(csv_path26)#קובץ של מבחן אולטימטום של נבדק עשרים ושש, ייצוג של דאטה פריים 
df_SUB1276ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1276ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1276\sub-1276_task-ultimatum_run-0_raw.csv')
#df_SUB1276ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים ושש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         23    1  1.5        10         7  1.0
# 1            2       2      1         17    1  3.0         8         1  1.0
# 2            3       3      2         15    3  3.0         5         1  1.0
# 3            4       4      3         17    1  4.5         3         0  1.0
# 4            5       5      2         19    3  3.0         4         6  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset   resp          rt  \
# 0    0.0  ...   6.007142    7.523072        7.523271    3.0    1.700086
# 1    1.0  ...  14.056787   17.073143       17.073303  999.0  999.000000
# 2    2.0  ...  23.623505   26.639524       26.639685    3.0    0.966995
# 3    3.0  ...  35.173286   39.689697       39.689896    2.0    1.783498
# 4    4.0  ...  46.223324   49.239780       49.239944    2.0    1.483203
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.223357        11.040607       3.518128  11.041617  12.046018
# 1  999.000000        20.089733       3.533159  20.606653  21.611042
# 2   27.606680        30.157034       3.518024  30.157840  33.162080
# 3   41.473392        43.206455       3.517267  43.207333  44.211636
# 4   50.723150        52.756588       3.517324  52.757400  55.761700
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 27

# %%
csv_path27 = r'sourcedata\UGDG\logs\1282\sub-1282_task-ultimatum_run-0_practice_raw.csv'
df_SUB1282ULTIMATUM = pd.read_csv(csv_path27)#קובץ של מבחן אולטימטום של נבדק עשרים ושבע, ייצוג של דאטה פריים 
df_SUB1282ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1282ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1282\sub-1282_task-ultimatum_run-0_practice_raw.csv')
#df_SUB1282ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים ושבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         17    5  3.0         5         3  1.0
# 1            2       2      2         19    1  4.5         1         4  1.0
# 2            3       3      1         15    8  1.5         3         7  1.0
# 3            4       4      1         17    3  1.5         5         8  1.0
# 4            5       5      2         23    1  1.5         1         7  1.0
#
#   order  ...  ISI_onset ISI_offset decision_onset   resp         rt  \
# 0   0.0  ...  6.0247626   9.030298       9.030455  999.0      999.0
# 1   1.0  ...  19.586515  24.091923      24.092047    3.0  1.2478563
# 2   2.0  ...  30.632244   32.13759      32.137714    2.0  1.2911818
# 3   3.0  ...   45.67725    47.1826       47.18272    3.0  1.0898901
# 4   4.0  ...   55.72329   57.22919      57.229317    2.0  1.0670251
#
#   resp_onset decision_offset trialDuration   ITIonset  ITIoffset
# 0      999.0       12.046796     3.5333793  12.564034  17.569431
# 1  25.339903       27.609566     3.5180998   27.61028  28.615623
# 2  33.428894        35.65439     3.5172374  35.655083  43.660435
# 3   48.27261       50.700256        3.5182   50.70105   53.70646
# 4   58.29634        60.74575     3.5170288  60.746475  61.751892
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 28

# %%
csv_path28 = r'sourcedata\UGDG\logs\1286\sub-1286_task-ultimatum_run-0_raw.csv'
df_SUB1286ULTIMATUM = pd.read_csv(csv_path28)#קובץ של מבחן אולטימטום של נבדק עשרים ושמונה, ייצוג של דאטה פריים 
df_SUB1286ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1286ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1286\sub-1286_task-ultimatum_run-0_raw.csv')
#df_SUB1286ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים ושמונה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         15    1  1.5         5         1  1.0
# 1            2       2      3         21    1  1.5         1         0  1.0
# 2            3       3      2         21    5  1.5         7         4  1.0
# 3            4       4      3         19    1  3.0         0         6  1.0
# 4            5       5      2         15    1  1.5         7         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.007776    7.523936        7.524138   2.0  1.750473
# 1    1.0  ...  14.058020   15.574270       15.574461   3.0  1.833275
# 2    2.0  ...  22.107890   23.624266       23.624416   3.0  1.816639
# 3    3.0  ...  34.157803   37.174644       37.174835   2.0  1.616497
# 4    4.0  ...  43.707783   45.224340       45.224495   2.0  1.316493
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.274611        11.041706       3.518015  11.042296  12.046390
# 1   17.407736        19.090704       3.516593  19.091175  20.095163
# 2   25.441053        27.140734       3.516662  27.141195  32.145115
# 3   38.791332        40.691340       3.516882  40.691840  41.695730
# 4   46.540990        48.741714       3.517574  48.742188  49.746320
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 29

# %%
csv_path29 = r'sourcedata\UGDG\logs\1294\sub-1294_task-ultimatum_run-0_raw.csv'
df_SUB1294ULTIMATUM = pd.read_csv(csv_path29)#קובץ של מבחן אולטימטום של נבדק עשרים ותשע, ייצוג של דאטה פריים 
df_SUB1294ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB1294ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1294\sub-1294_task-ultimatum_run-0_raw.csv ')
#df_SUB1294ULTIMATUM #קובץ של מבחן אולטימטום של נבדק עשרים ותשע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         17    3  1.5         8         5  1.0
# 1            2       2      1         19    1  3.0         4         1  1.0
# 2            3       3      1         23    8  3.0         4        10  1.0
# 3            4       4      1         19    1  1.5         1         9  1.0
# 4            5       5      2         15    5  3.0         1         5  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.021780    7.537972        7.538166   2.0  1.400340
# 1    1.0  ...  16.071598   19.088223       19.088377   2.0  1.266724
# 2    2.0  ...  25.621696   28.638054       28.638205   3.0  1.600352
# 3    3.0  ...  42.171880   43.688038       43.688305   3.0  1.633570
# 4    4.0  ...  50.221508   53.237843       53.238000   3.0  1.833520
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.938506        11.054673       3.516980  11.055293  14.059957
# 1   20.355100        22.605255       3.517227  22.605720  23.609816
# 2   30.238558        32.154716       3.516857  32.155178  40.159240
# 3   45.321877        47.204870       3.516908  47.205334  48.209618
# 4   55.071518        56.754997       3.517346  56.755463  61.758926
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 30

# %%
csv_path30 = r'sourcedata\UGDG\logs\1300\sub-1300_task-ultimatum_run-0_raw.csv'
df_SUB1300ULTIMATUM = pd.read_csv(csv_path30)#קובץ של מבחן אולטימטום של נבדק שלושים, ייצוג של דאטה פריים 
df_SUB1300ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1300ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1300\sub-1300_task-ultimatum_run-0_raw.csv ')
#df_SUB1300ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         17    1  3.0         3         0  1.0
# 1            2       2      1         25    1  3.0         2        11  1.0
# 2            3       3      3         25    3  4.5         0         5  1.0
# 3            4       4      2         19    3  3.0         4         1  1.0
# 4            5       5      1         21    1  1.5         4         9  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.019011    9.035276        9.035504   2.0  2.333571
# 1    1.0  ...  15.569035   18.584587       18.584743   2.0  0.617721
# 2    2.0  ...  25.119093   29.635212       29.635397   3.0  2.233558
# 3    3.0  ...  38.169296   41.185220       41.185375   2.0  1.466905
# 4    4.0  ...  49.719013   51.235443       51.235603   3.0  1.616760
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.369075        12.552228       3.517210  12.552862  13.556750
# 1   19.202465        22.101852       3.517453  22.102312  23.106224
# 2   31.868956        33.152534       3.517484  33.153000  36.157100
# 3   42.652283        44.702515       3.517485  44.702980  47.707104
# 4   52.852364        54.752525       3.517271  54.752990  55.757526
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 31

# %%
csv_path31 = r'sourcedata\UGDG\logs\1301\sub-1301_task-ultimatum_run-0_raw.csv'
df_SUB1301ULTIMATUM = pd.read_csv(csv_path31)#קובץ של מבחן אולטימטום של נבדק שלושים ואחד, ייצוג של דאטה פריים 
df_SUB1301ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1301ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1301\sub-1301_task-ultimatum_run-0_raw.csv')
#df_SUB1301ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים ואחד, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         17    1  1.5         5         1  1.0
# 1            2       2      3         23    1  1.5         1         0  1.0
# 2            3       3      1         17    3  3.0         8         1  1.0
# 3            4       4      1         17    1  1.5         3         8  1.0
# 4            5       5      3         17    1  1.5         0         8  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset   resp          rt  \
# 0    0.0  ...   6.008572    7.524682        7.524878    2.0    2.403299
# 1    1.0  ...  14.048519   15.564751       15.564945  999.0  999.000000
# 2    2.0  ...  22.105078   25.121440       25.121660    2.0    1.370562
# 3    3.0  ...  33.647865   35.164352       35.164547    3.0    1.402400
# 4    4.0  ...  41.687794   43.204178       43.204370    3.0    2.203423
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.928177        11.041770       3.517669  11.042705  12.046877
# 1  999.000000        18.568474       3.520773  19.085900  20.090076
# 2   26.492222        28.638353       3.517407  28.639210  31.643396
# 3   36.566948        38.681396       3.517518  38.682198  39.686900
# 4   45.407790        46.721085       3.517383  46.721880  47.726006
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 32

# %%
csv_path32 = r'sourcedata\UGDG\logs\1302\sub-1302_task-ultimatum_run-0_raw.csv'
df_SUB1302ULTIMATUM = pd.read_csv(csv_path32)#קובץ של מבחן אולטימטום של נבדק שלושים ושתיים, ייצוג של דאטה פריים 
df_SUB1302ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1302ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1302\sub-1302_task-ultimatum_run-0_raw.csv ')
#df_SUB1302ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים ושתיים, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         19    3  1.5         0         9  1.0
# 1            2       2      1         23    8  1.5         4         7  1.0
# 2            3       3      1         15    3  3.0         7         5  1.0
# 3            4       4      2         25    5  1.5         8         2  1.0
# 4            5       5      2         19    1  1.5         9         6  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.019013    7.535099        7.535325   3.0  1.268968
# 1    1.0  ...  16.060230   17.576323       17.576483   3.0  1.686702
# 2    2.0  ...  31.106040   34.122765       34.122925   3.0  1.186562
# 3    3.0  ...  42.648937   44.165417       44.165585   3.0  0.818616
# 4    4.0  ...  54.692284   56.208805       56.208965   3.0  1.185442
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.804295        11.052798       3.518267  11.053760  14.058062
# 1   19.263186        21.093407       3.517616  21.094230  29.098415
# 2   35.309486        37.639282       3.517037  37.640095  40.644220
# 3   44.984200        47.682537       3.517648  47.683370  52.687610
# 4   57.394410        59.725758       3.517459  59.726560  60.731530
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 33

# %%
csv_path33 = r'sourcedata\UGDG\logs\1303\sub-1303_task-ultimatum_run-0_raw.csv'
df_SUB1303ULTIMATUM = pd.read_csv(csv_path33)#קובץ של מבחן אולטימטום של נבדק שלושים ושלוש, ייצוג של דאטה פריים 
df_SUB1303ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB1303ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\1303\sub-1303_task-ultimatum_run-0_raw.csv')
#df_SUB1303ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים ושלוש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         23    1  1.5         0         1  1.0
# 1            2       2      2         17    3  4.5         5         8  1.0
# 2            3       3      2         15    1  3.0         3         5  1.0
# 3            4       4      1         21    3  1.5         9         1  1.0
# 4            5       5      1         21    1  1.5         7         4  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.016731    7.532923        7.533091   3.0  1.767038
# 1    1.0  ...  14.066573   18.583893       18.584005   2.0  1.216270
# 2    2.0  ...  27.116564   30.132925       30.133036   2.0  1.117099
# 3    3.0  ...  36.666640   38.182920       38.183033   2.0  1.734026
# 4    4.0  ...  46.716644   48.232986       48.233097   2.0  1.167331
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.300129        11.050884       3.518409  11.051621  12.052960
# 1   19.800276        22.101042       3.517564  22.101670  25.102896
# 2   31.250135        33.650540       3.518027  33.651165  34.651900
# 3   39.917057        41.698990       3.516484  41.699620  44.700870
# 4   49.400430        51.749886       3.517307  51.750507  52.751915
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 34

# %%
csv_path34 = r'sourcedata\UGDG\logs\3101\sub-3101_task-ultimatum_run-0_raw.csv'
df_SUB3101ULTIMATUM = pd.read_csv(csv_path34)#קובץ של מבחן אולטימטום של נבדק שלושים וארבע, ייצוג של דאטה פריים 
df_SUB3101ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3101ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3101\sub-3101_task-ultimatum_run-0_raw.csv')
#df_SUB3101ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים וארבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         17    3  1.5         8         0  1.0
# 1            2       2      3         25    8  1.5         2         0  1.0
# 2            3       3      3         17    1  3.0         3         0  1.0
# 3            4       4      1         25    1  3.0         2         5  1.0
# 4            5       5      3         21    1  3.0         0         9  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.016881    7.533320        7.533553   2.0  1.333383
# 1    1.0  ...  16.066854   17.583172       17.583363   3.0  0.900141
# 2    2.0  ...  31.116796   34.133300       34.133490   2.0  1.050317
# 3    3.0  ...  40.666940   43.683650       43.683810   2.0  1.616361
# 4    4.0  ...  50.216750   53.233284       53.233467   2.0  1.317012
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.866936        11.050288       3.517537  11.051248  14.054576
# 1   18.483503        21.099764       3.517078  21.100576  29.104805
# 2   35.183807        37.650000       3.517201  37.650820  38.654810
# 3   45.300170        47.200440       3.517303  47.201244  48.205624
# 4   54.550480        56.749413       3.516614  56.750210  57.754240
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 35

# %%
csv_path35 = r'sourcedata\UGDG\logs\3116\sub-3116_task-ultimatum_run-0_raw.csv'
df_SUB3116ULTIMATUM = pd.read_csv(csv_path35)#קובץ של מבחן אולטימטום של נבדק שלושים וחמש, ייצוג של דאטה פריים 
df_SUB3116ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3116ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3116\sub-3116_task-ultimatum_run-0_raw.csv')
#df_SUB3116ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים וחמש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         17    5  4.5         1         3  1.0
# 1            2       2      1         25    5  1.5         8        11  1.0
# 2            3       3      3         21    3  4.5         9         0  1.0
# 3            4       4      1         17    1  3.0         8         1  1.0
# 4            5       5      2         15    1  1.5         5         7  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.019875   10.536625       10.536823   3.0  1.482870
# 1    1.0  ...  21.069859   22.586290       22.586452   2.0  1.433351
# 2    2.0  ...  33.119846   37.636513       37.636715   2.0  1.416652
# 3    3.0  ...  46.169647   49.186230       49.186410   2.0  1.683306
# 4    4.0  ...  55.719624   57.235960       57.236122   2.0  1.016765
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   12.019693        14.054268       3.518255  14.055270  19.060583
# 1   24.019804        26.103155       3.517383  26.103968  31.108305
# 2   39.053368        41.154500       3.518471  41.155327  44.160060
# 3   50.869717        52.703210       3.517506  52.704063  53.708020
# 4   58.252888        60.753147       3.517710  60.753967  61.758167
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 36

# %%
csv_path36 = r'sourcedata\UGDG\logs\3122\sub-3122_task-ultimatum_run-0_raw.csv'
df_SUB3122ULTIMATUM = pd.read_csv(csv_path36)#קובץ של מבחן אולטימטום של נבדק שלושים ושש, ייצוג של דאטה פריים 
df_SUB3122ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB3122ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3122\sub-3122_task-ultimatum_run-0_raw.csv')
#df_SUB3122ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים ושש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         15    1  1.5         1         5  1.0
# 1            2       2      2         19    5  1.5         4         1  1.0
# 2            3       3      1         25    1  4.5         2         5  1.0
# 3            4       4      3         17    1  4.5         3         0  1.0
# 4            5       5      2         21    1  1.5         1         7  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.019228    7.536015        7.536206   2.0  0.866443
# 1    1.0  ...  14.068776   15.585068       15.585225   3.0  1.350269
# 2    2.0  ...  26.118647   30.635477       30.635637   3.0  1.100112
# 3    3.0  ...  37.168446   41.684948       41.685143   3.0  2.833297
# 4    4.0  ...  48.218640   49.735610       49.735764   2.0  1.232726
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.402650        11.052122       3.516734  11.053104  12.058540
# 1   16.935493        19.101763       3.517204  19.102558  24.107386
# 2   31.735748        34.151646       3.516655  34.152424  35.156853
# 3   44.518436        45.201878       3.517413  45.202705  46.207092
# 4   50.968490        53.252533       3.517425  53.253323  54.257810
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 37

# %%
csv_path37 = r'sourcedata\UGDG\logs\3125\sub-3125_task-ultimatum_run-0_raw.csv'
df_SUB3125ULTIMATUM = pd.read_csv(csv_path37)#קובץ של מבחן אולטימטום של נבדק שלושים ושבע, ייצוג של דאטה פריים 
df_SUB3125ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB3125ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3125\sub-3125_task-ultimatum_run-0_raw.csv')
#df_SUB3125ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים ושבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         25    5  3.0         5         8  1.0
# 1            2       2      1         19    3  1.5         6         4  1.0
# 2            3       3      1         17    1  3.0         8         1  1.0
# 3            4       4      2         15    1  1.5         5         1  1.0
# 4            5       5      1         25    5  4.5         5         8  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.008031    9.024546        9.024740   3.0  1.533315
# 1    1.0  ...  19.557955   21.074425       21.074585   2.0  1.816630
# 2    2.0  ...  29.607689   32.624374       32.624540   2.0  2.900061
# 3    3.0  ...  39.157955   40.674300       40.674460   2.0  1.450066
# 4    4.0  ...  47.207592   51.724167       51.724327   3.0  2.600176
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.558055        12.541574       3.517609  12.542506  17.547565
# 1   22.891216        24.591470       3.517559  24.592276  27.596756
# 2   35.524600        36.140870       3.517000  36.141674  37.145836
# 3   42.124527        44.190742       3.516958  44.191550  45.196148
# 4   54.324505        55.241410       3.517749  55.242210  60.246548
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 38

# %%
csv_path38 = r'sourcedata\UGDG\logs\3140\sub-3140_task-ultimatum_run-0_raw.csv'
df_SUB3140ULTIMATUM = pd.read_csv(csv_path38)#קובץ של מבחן אולטימטום של נבדק שלושים ושמונה, ייצוג של דאטה פריים 
df_SUB3140ULTIMATUM.head() #רק 5 שורות ראשונות
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         23    5  1.5         1         7  1.0
# 1            2       2      1         23    5  1.5         4        10  1.0
# 2            3       3      2         25    1  3.0        11         5  1.0
# 3            4       4      2         23    1  1.5         7         4  1.0
# 4            5       5      1         17    3  1.5         5         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.013573    7.530596        7.530796   2.0  0.849316
# 1    1.0  ...  18.063488   19.579525       19.579687   3.0  1.233422
# 2    2.0  ...  30.113245   33.129470       33.129627   3.0  1.399984
# 3    3.0  ...  39.663170   41.179962       41.180120   3.0  0.916661
# 4    4.0  ...  47.713184   49.229527       49.229687   3.0  1.867019
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.380112        11.047490       3.517479  11.048439  16.053043
# 1   20.813108        23.097517       3.518510  23.098331  28.102901
# 2   34.529613        36.647236       3.518261  36.648020  37.652330
# 3   42.096780        44.697105       3.517651  44.697906  45.702606
# 4   51.096703        52.745384       3.516361  52.746180  55.751300
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 39

# %%
csv_path39 = r'sourcedata\UGDG\logs\3143\sub-3143_task-ultimatum_run-0_raw.csv'
df_SUB3143ULTIMATUM = pd.read_csv(csv_path39)#קובץ של מבחן אולטימטום של נבדק שלושים ותשע, ייצוג של דאטה פריים 
df_SUB3143ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3143ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3143\sub-3143_task-ultimatum_run-0_raw.csv')
#df_SUB3143ULTIMATUM #קובץ של מבחן אולטימטום של נבדק שלושים ותשע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         21    1  1.5         0         1  1.0
# 1            2       2      1         25    3  1.5         5        11  1.0
# 2            3       3      1         25    8  1.5         2        11  1.0
# 3            4       4      3         19    8  3.0         0         4  1.0
# 4            5       5      2         15    1  4.5         7         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.007323    7.523748        7.523993   2.0  2.620189
# 1    1.0  ...  14.047549   15.564562       15.564729   2.0  1.017824
# 2    2.0  ...  24.088852   25.605553       25.605717   3.0  0.835196
# 3    3.0  ...  39.134624   42.151104       42.151302   2.0  1.853878
# 4    4.0  ...  55.682170   60.198050       60.198210   3.0  1.405027
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.144182        11.040504       3.517343  11.041503  12.045819
# 1   16.582552        19.082296       3.518275  19.083176  22.087560
# 2   26.440912        29.122534       3.517515  29.123392  37.127950
# 3   44.005180        45.669586       3.518991  45.670450  53.675625
# 4   61.603237        63.714626       3.517151  63.715523  64.720610
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 40

# %%
csv_path40 = r'sourcedata\UGDG\logs\3152\sub-3152_task-ultimatum_run-0_raw.csv'
df_SUB3152ULTIMATUM = pd.read_csv(csv_path40)#קובץ של מבחן אולטימטום של נבדק ארבעים, ייצוג של דאטה פריים 
df_SUB3152ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3152ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3152\sub-3152_task-ultimatum_run-0_raw.csv')
#df_SUB3152ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         19    1  3.0         0         9  1.0
# 1            2       2      3         17    1  1.5         3         0  1.0
# 2            3       3      3         17    1  3.0         0         3  1.0
# 3            4       4      3         17    3  1.5         0         8  1.0
# 4            5       5      3         15    5  4.5         1         0  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.007548    9.024141        9.024369   3.0  2.370782
# 1    1.0  ...  15.548637   17.065096       17.065285   3.0  1.118924
# 2    2.0  ...  23.605175   26.621890       26.622076   2.0  1.637123
# 3    3.0  ...  33.146507   34.663330       34.663520   3.0  1.218819
# 4    4.0  ...  43.188080   47.704536       47.704735   3.0  1.888779
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.395151        12.541638       3.518067  12.542602  13.546635
# 1   18.184208        20.582695       3.518111  20.583544  21.588747
# 2   28.259201        30.138538       3.517149  30.139360  31.143452
# 3   35.882340        38.180780       3.517927  38.181580  41.185757
# 4   49.593513        51.222614       3.518549  51.223420  56.227543
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 41

# %%
csv_path41 = r'sourcedata\UGDG\logs\3164\sub-3164_task-ultimatum_run-0_raw.csv'
df_SUB3164ULTIMATUM = pd.read_csv(csv_path41)#קובץ של מבחן אולטימטום של נבדק ארבעים ואחד, ייצוג של דאטה פריים 
df_SUB3164ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3164ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3164\sub-3164_task-ultimatum_run-0_raw.csv')
#df_SUB3164ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים ואחד, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         21    1  1.5         1         0  1.0
# 1            2       2      1         23    5  1.5        10         7  1.0
# 2            3       3      1         15    3  3.0         5         1  1.0
# 3            4       4      3         21    1  1.5         7         0  1.0
# 4            5       5      2         19    1  1.5         4         9  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.014502    7.530943        7.531184   3.0  1.299971
# 1    1.0  ...  14.064515   15.581528       15.581687   3.0  2.032673
# 2    2.0  ...  26.114428   29.130934       29.131090   2.0  1.466588
# 3    3.0  ...  37.664337   39.180880       39.181072   2.0  1.366799
# 4    4.0  ...  45.714325   47.231430       47.231590   2.0  1.982560
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.831154        11.048474       3.518073  11.049421  12.053652
# 1   17.614359        19.099049       3.518045  19.099869  24.104195
# 2   30.597680        32.648483       3.518056  32.649277  35.653330
# 3   40.547870        42.698116       3.517707  42.698910  43.703064
# 4   49.214150        50.748620       3.517691  50.749413  51.753920
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 42

# %%
csv_path42 = r'sourcedata\UGDG\logs\3166\sub-3166_task-ultimatum_run-0_raw.csv'
df_SUB3166ULTIMATUM = pd.read_csv(csv_path42)#קובץ של מבחן אולטימטום של נבדק ארבעים ושתיים, ייצוג של דאטה פריים 
df_SUB3166ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3166ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3166\sub-3166_task-ultimatum_run-0_raw.csv ')
#df_SUB3166ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים ושציים, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         17    3  3.0         3         1  1.0
# 1            2       2      2         23    5  1.5        10         4  1.0
# 2            3       3      2         19    1  3.0         6         9  1.0
# 3            4       4      1         17    3  4.5         3         5  1.0
# 4            5       5      3         21    5  4.5         4         0  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset   resp          rt  \
# 0    0.0  ...   6.010543    9.026729        9.026931    2.0    0.916305
# 1    1.0  ...  17.560345   19.076176       19.076342    3.0    1.367114
# 2    2.0  ...  29.610054   32.626240       32.626404    2.0    1.166888
# 3    3.0  ...  39.159912   43.676334       43.676500    3.0    1.800276
# 4    4.0  ...  52.209988   56.726320       56.726517  999.0  999.000000
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.943236        12.543786       3.517646  12.544752  15.549256
# 1   20.443457        22.592981       3.517342  22.593824  27.598404
# 2   33.793290        36.143604       3.517879  36.144417  37.149590
# 3   45.476772        47.193570       3.517744  47.194374  50.199543
# 4  999.000000        59.742706       3.533721  60.260437  65.264300
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 43

# %%
csv_path43 = r'sourcedata\UGDG\logs\3167\sub-3167_task-ultimatum_run-0_raw.csv'
df_SUB3167ULTIMATUM = pd.read_csv(csv_path43)#קובץ של מבחן אולטימטום של נבדק ארבעים ושלוש, ייצוג של דאטה פריים 
df_SUB3167ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3167ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3167\sub-3167_task-ultimatum_run-0_raw.csv')
#df_SUB3167ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים ושלוש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         25    1  1.5         8         0  1.0
# 1            2       2      3         15    1  1.5         1         0  1.0
# 2            3       3      3         15    8  1.5         0         1  1.0
# 3            4       4      1         15    5  3.0         3         5  1.0
# 4            5       5      1         17    1  1.5         8         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.020732    7.536861        7.537090   3.0  2.100262
# 1    1.0  ...  14.070577   15.587221       15.587415   3.0  2.083228
# 2    2.0  ...  22.120676   23.637241       23.637432   3.0  1.466374
# 3    3.0  ...  37.170742   40.187572       40.187730   2.0  1.816479
# 4    4.0  ...  50.720573   52.237440       52.237595   2.0  1.732913
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.637353        11.053921       3.517795  11.055047  12.059251
# 1   17.670643        19.104725       3.518026  19.105602  20.110003
# 2   25.103806        27.154420       3.517647  27.155210  35.160520
# 3   42.004208        43.704450       3.517386  43.705254  48.710426
# 4   53.970510        55.755135       3.518208  55.755936  56.760254
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 44

# %%
csv_path44 = r'sourcedata\UGDG\logs\3170\sub-3170_task-ultimatum_run-0_raw.csv'
df_SUB3170ULTIMATUM = pd.read_csv(csv_path44)#קובץ של מבחן אולטימטום של נבדק ארבעים וארבע, ייצוג של דאטה פריים 
df_SUB3170ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3170ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3170\sub-3170_task-ultimatum_run-0_raw.csv')
#df_SUB3170ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים ואבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         19    1  1.5         1         6  1.0
# 1            2       2      2         15    1  1.5         7         3  1.0
# 2            3       3      1         15    3  3.0         5         7  1.0
# 3            4       4      3         19    1  4.5         0         6  1.0
# 4            5       5      3         21    1  3.0         0         4  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.018035    7.535754        7.535904   2.0  2.915158
# 1    1.0  ...  14.067986   15.584444       15.584563   3.0  1.934181
# 2    2.0  ...  22.117966   25.135980       25.136095   3.0  1.549235
# 3    3.0  ...  33.668304   38.185966       38.186108   3.0  2.515522
# 4    4.0  ...  44.717880   47.734997       47.735153   2.0  1.550158
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.451063        11.053383       3.518108  11.054137  12.055943
# 1   17.518745        19.100992       3.516971  19.101639  20.102636
# 2   26.685330        28.652102       3.516537  28.652733  31.653961
# 3   40.701630        41.703970       3.518390  41.704600  42.708374
# 4   49.285313        51.250996       3.516371  51.251625  52.253654
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 45

# %%
csv_path45 = r'sourcedata\UGDG\logs\3173\sub-3173_task-ultimatum_run-0_raw.csv'
df_SUB3173ULTIMATUM = pd.read_csv(csv_path45)#קובץ של מבחן אולטימטום של נבדק ארבעים וחמש, ייצוג של דאטה פריים 
df_SUB3173ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3173ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3173\sub-3173_task-ultimatum_run-0_raw.csv ')
#df_SUB3173ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים וחמש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         21    5  4.5         0         7  1.0
# 1            2       2      2         23    1  1.5         4         7  1.0
# 2            3       3      1         15    1  3.0         3         1  1.0
# 3            4       4      3         21    1  1.5         0         1  1.0
# 4            5       5      2         17    1  1.5         1         5  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.018732   10.534976       10.535206   3.0  2.649995
# 1    1.0  ...  21.068602   22.585571       22.585743   2.0  1.015977
# 2    2.0  ...  29.118418   32.134533       32.134693   2.0  1.583689
# 3    3.0  ...  38.668205   40.184856       40.185055   2.0  1.966803
# 4    4.0  ...  46.718334   48.234470       48.234634   2.0  0.817248
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   13.185201        14.053188       3.518967  14.054340  19.058487
# 1   23.601719        26.103006       3.517973  26.103874  27.109580
# 2   33.718384        35.651714       3.517719  35.652580  36.656815
# 3   42.151855        43.702210       3.517877  43.703110  44.707657
# 4   49.051880        51.750910       3.516998  51.751793  52.757004
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 46

# %%
csv_path46 = r'sourcedata\UGDG\logs\3175\sub-3175_task-ultimatum_run-0_raw.csv'
df_SUB3175ULTIMATUM = pd.read_csv(csv_path46)#קובץ של מבחן אולטימטום של נבדק ארבעים ושש, ייצוג של דאטה פריים 
df_SUB3175ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3175ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3175\sub-3175_task-ultimatum_run-0_raw.csv')
#df_SUB3175ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים ושש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         25    3  4.5        11         0  1.0
# 1            2       2      1         25    1  1.5         5         8  1.0
# 2            3       3      3         15    8  4.5         0         1  1.0
# 3            4       4      1         21    1  3.0         9         1  1.0
# 4            5       5      1         19    1  1.5         1         6  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.025764   10.542173       10.542335   2.0  1.267240
# 1    1.0  ...  19.076141   20.592068       20.592182   3.0  1.567381
# 2    2.0  ...  27.126055   31.644028       31.644163   3.0  1.282196
# 3    3.0  ...  45.175610   48.193070       48.193184   3.0  1.699687
# 4    4.0  ...  54.725662   56.243004       56.243120   3.0  1.465741
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.809574        14.058783       3.517066  14.059523  17.061031
# 1   22.159563        24.109228       3.517570  24.109850  25.111000
# 2   32.926357        35.161030       3.517412  35.161690  43.163147
# 3   49.892870        51.709720       3.517092  51.710392  52.712017
# 4   57.708860        59.762028       3.519429  59.762660  60.764458
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 47

# %%
csv_path47 = r'sourcedata\UGDG\logs\3176\sub-3176_task-ultimatum_run-0_raw.csv'
df_SUB3176ULTIMATUM = pd.read_csv(csv_path47)#קובץ של מבחן אולטימטום של נבדק ארבעים ושבע, ייצוג של דאטה פריים 
df_SUB3176ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB3176ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3176\sub-3176_task-ultimatum_run-0_raw.csv')
#df_SUB3176ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים שבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         21    1  1.5         0         1  1.0
# 1            2       2      3         17    3  4.5         5         0  1.0
# 2            3       3      3         17    5  3.0         0         3  1.0
# 3            4       4      3         25    1  1.5        11         0  1.0
# 4            5       5      3         25    3  4.5         2         0  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.013219    7.529194        7.529422   3.0  2.233527
# 1    1.0  ...  14.062845   18.579184       18.579374   3.0  2.083584
# 2    2.0  ...  27.112730   30.128986       30.129180   2.0  1.650300
# 3    3.0  ...  40.662594   42.179040       42.179230   2.0  1.366871
# 4    4.0  ...  48.712660   53.229053       53.229250   3.0  2.183201
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.762950        11.046117       3.517523  11.047113  12.051438
# 1   20.662958        22.096363       3.517708  22.097248  25.101542
# 2   31.779482        33.645767       3.517294  33.646614  38.651577
# 3   43.546100        45.696407       3.517890  45.697258  46.702530
# 4   55.412453        56.746796       3.518279  56.747665  59.752483
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 48

# %%
csv_path48 = r'sourcedata\UGDG\logs\3186\sub-3186_task-ultimatum_run-0_raw.csv'
df_SUB3186ULTIMATUM = pd.read_csv(csv_path48)#קובץ של מבחן אולטימטום של נבדק ארבעים ושמונה, ייצוג של דאטה פריים 
df_SUB3186ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB3186ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3186\sub-3186_task-ultimatum_run-0_raw.csv')
#df_SUB3186ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים ושמונה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         23    1  1.5        10         0  1.0
# 1            2       2      3         25    1  4.5         2         0  1.0
# 2            3       3      3         25    3  1.5         2         0  1.0
# 3            4       4      1         25    3  4.5         8         5  1.0
# 4            5       5      2         15    3  3.0         1         7  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset   resp          rt  \
# 0    0.0  ...   6.019381    7.537102        7.537273    2.0    2.649389
# 1    1.0  ...  14.069316   18.586813       18.586958    3.0    2.183728
# 2    2.0  ...  25.119137   26.636148       26.636286    3.0    1.850602
# 3    3.0  ...  35.169357   39.686928       39.687042  999.0  999.000000
# 4    4.0  ...  48.235992   51.253197       51.253310    2.0    1.333511
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.186663        11.053065       3.516402  11.053796  12.055050
# 1   20.770685        22.103966       3.517533  22.104595  23.106125
# 2   28.486887        30.152075       3.516305  30.152690  33.154083
# 3  999.000000        42.702470       3.533348  43.220528  46.222134
# 4   52.586823        54.770035       3.517249  54.770660  57.771732
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 49

# %%
csv_path49 = r'sourcedata\UGDG\logs\3189\sub-3189_task-ultimatum_run-0_raw.csv'
df_SUB3189ULTIMATUM = pd.read_csv(csv_path49)#קובץ של מבחן אולטימטום של נבדק ארבעים ותשע, ייצוג של דאטה פריים 
df_SUB3189ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3189ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3189\sub-3189_task-ultimatum_run-0_raw.csv')
#df_SUB3189ULTIMATUM #קובץ של מבחן אולטימטום של נבדק ארבעים ותשע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         15    3  1.5         3         0  1.0
# 1            2       2      3         25    1  1.5        11         0  1.0
# 2            3       3      3         23    3  1.5         4         0  1.0
# 3            4       4      2         21    1  1.5         9         4  1.0
# 4            5       5      1         23    3  3.0        10         7  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.011730    7.527775        7.527946   2.0  1.833868
# 1    1.0  ...  16.060957   17.578505       17.578650   2.0  1.015789
# 2    2.0  ...  24.110890   25.627771       25.627910   2.0  1.183707
# 3    3.0  ...  34.160640   35.677895       35.678010   2.0  1.416001
# 4    4.0  ...  42.210854   45.227770       45.227886   2.0  1.266194
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.361814        11.044834       3.517521  11.045596  14.046432
# 1   18.594439        21.096903       3.518779  21.097538  22.098616
# 2   26.811617        29.145817       3.518484  29.146496  32.147510
# 3   37.094013        39.195860       3.518381  39.196495  40.197906
# 4   46.494080        48.746338       3.518993  48.746980  51.748726
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 50

# %%
csv_path50 = r'sourcedata\UGDG\logs\3190\sub-3190_task-ultimatum_run-0_raw.csv'
df_SUB3190ULTIMATUM = pd.read_csv(csv_path50)#קובץ של מבחן אולטימטום של נבדק חמישים, ייצוג של דאטה פריים 
df_SUB3190ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3190ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3190\sub-3190_task-ultimatum_run-0_raw.csv ')
#df_SUB3190ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים , ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         23    3  1.5        10         4  1.0
# 1            2       2      1         23    1  1.5        10         7  1.0
# 2            3       3      1         19    5  1.5         4         1  1.0
# 3            4       4      1         21    1  4.5         9         4  1.0
# 4            5       5      2         15    3  3.0         1         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.013119    7.529894        7.530041   2.0  0.849823
# 1    1.0  ...  16.062365   17.578920       17.579035   3.0  1.333921
# 2    2.0  ...  24.112616   25.629890       25.630005   3.0  0.850288
# 3    3.0  ...  36.162373   40.679913       40.680027   3.0  1.065829
# 4    4.0  ...  47.212376   50.228844       50.228960   3.0  2.850955
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.379865        11.046883       3.517468  11.047632  14.048597
# 1   18.912956        21.096848       3.518345  21.097479  22.099880
# 2   26.480293        29.145576       3.516097  29.146204  34.147507
# 3   41.745853        44.198196       3.518694  44.198820  45.201576
# 4   53.079914        53.745895       3.517465  53.746530  56.747894
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 51

# %%
csv_path51 = r'sourcedata\UGDG\logs\3199\sub-3199_task-ultimatum_run-0_raw.csv'
df_SUB3199ULTIMATUM = pd.read_csv(csv_path51)#קובץ של מבחן אולטימטום של נבדק חמישים ואחד, ייצוג של דאטה פריים 
df_SUB3199ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3199ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3199\sub-3199_task-ultimatum_run-0_raw.csv')
#df_SUB3199ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים ואחד, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         17    1  4.5         8         1  1.0
# 1            2       2      3         23    1  1.5         0         7  1.0
# 2            3       3      2         23    1  1.5        10         4  1.0
# 3            4       4      3         21    3  3.0         7         0  1.0
# 4            5       5      1         17    1  4.5         1         3  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset   resp          rt  \
# 0    0.0  ...   6.017216   10.534285       10.534424  999.0  999.000000
# 1    1.0  ...  17.083605   18.600843       18.600980    2.0    2.000410
# 2    2.0  ...  25.133492   26.650946       26.651064    2.0    2.315561
# 3    3.0  ...  33.183846   36.200043       36.200184    2.0    1.834681
# 4    4.0  ...  44.733723   49.250900       49.251020    3.0    1.916232
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0  999.000000        13.550159       3.533854  14.068446  15.069610
# 1   20.601390        22.115835       3.515390  22.116468  23.117746
# 2   28.966625        30.167974       3.517433  30.168613  31.170181
# 3   38.034866        39.715850       3.516199  39.716484  42.718407
# 4   51.167250        52.768806       3.518347  52.769524  53.770850
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 52

# %%
csv_path52 = r'sourcedata\UGDG\logs\3200\sub-3200_task-ultimatum_run-0_raw.csv'
df_SUB3200ULTIMATUM = pd.read_csv(csv_path52)#קובץ של מבחן אולטימטום של נבדק חמישים ושתיים, ייצוג של דאטה פריים 
df_SUB3200ULTIMATUM.head() #רק 5 שורות ראשונות 


#df_SUB3200ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3200\sub-3200_task-ultimatum_run-0_raw.csv')
#df_SUB3200ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים ושתיים, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         23    5  4.5         1        10  1.0
# 1            2       2      1         17    1  1.5         8         1  1.0
# 2            3       3      2         23    3  1.5         7        10  1.0
# 3            4       4      1         23    1  3.0         7         4  1.0
# 4            5       5      1         25    3  1.5         8        11  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.016111   10.533131       10.533278   2.0  0.007476
# 1    1.0  ...  21.049670   22.567055       22.567183   2.0  1.349726
# 2    2.0  ...  29.099820   30.616026       30.616142   2.0  0.966783
# 3    3.0  ...  39.149704   42.166370       42.166490   2.0  2.183569
# 4    4.0  ...  48.699730   50.216470       50.216583   2.0  2.300009
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.540754        14.042788       3.510145  14.043550  19.044256
# 1   23.916908        26.083443       3.516828  26.084118  27.085710
# 2   31.582926        34.133930       3.518327  34.134575  37.135628
# 3   44.350056        45.683468       3.517523  45.684116  46.685955
# 4   52.516590        53.732662       3.516626  53.733315  56.734720
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 53

# %%
csv_path53 = r'sourcedata\UGDG\logs\3206\sub-3206_task-ultimatum_run-0_raw.csv'
df_SUB3206ULTIMATUM = pd.read_csv(csv_path53)#קובץ של מבחן אולטימטום של נבדק חמישים ושלוש, ייצוג של דאטה פריים 
df_SUB3206ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3206ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3206\sub-3206_task-ultimatum_run-0_raw.csv ')
#df_SUB3206ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים ושלוש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         19    3  1.5         0         1  1.0
# 1            2       2      2         15    3  1.5         7         1  1.0
# 2            3       3      2         23    8  1.5         1         7  1.0
# 3            4       4      1         25    1  4.5         5        11  1.0
# 4            5       5      3         25    5  1.5         0         5  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.020844    7.538079        7.538248   2.0  1.466649
# 1    1.0  ...  16.070517   17.587004       17.587118   3.0  1.951004
# 2    2.0  ...  26.120700   27.637026       27.637142   2.0  1.534082
# 3    3.0  ...  41.170730   45.688072       45.688187   2.0  1.865671
# 4    4.0  ...  52.220970   53.737003       53.737140   2.0  2.600502
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.004896        11.055083       3.517492  11.055887  14.058089
# 1   19.538122        21.103083       3.516552  21.103792  24.105047
# 2   29.171225        31.153059       3.516464  31.153725  39.156193
# 3   47.553860        49.206240       3.518594  49.206882  50.208946
# 4   56.337643        57.253597       3.517073  57.254333  62.255028
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 54

# %%
csv_path54 = r'sourcedata\UGDG\logs\3210\sub-3210_task-ultimatum_run-0_raw.csv '
df_SUB3210ULTIMATUM = pd.read_csv(csv_path54)#קובץ של מבחן אולטימטום של נבדק חמישים וארבע, ייצוג של דאטה פריים 
df_SUB3210ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3210ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3210\sub-3210_task-ultimatum_run-0_raw.csv ')
#df_SUB3210ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים וארבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         15    3  3.0         1         7  1.0
# 1            2       2      2         23    8  1.5         7        10  1.0
# 2            3       3      1         15    1  4.5         1         5  1.0
# 3            4       4      3         23    1  4.5         7         0  1.0
# 4            5       5      3         19    3  1.5         6         0  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.021765    9.038929        9.039069   3.0  1.199750
# 1    1.0  ...  17.571278   19.087920       19.088032   2.0  1.484082
# 2    2.0  ...  32.621480   37.139866       37.139988   3.0  1.049019
# 3    3.0  ...  43.671204   48.187862       48.188010   2.0  1.416927
# 4    4.0  ...  54.721680   56.238840       56.238976   2.0  1.365871
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   10.238818        12.555797       3.517353  12.556547  15.557926
# 1   20.572113        22.604012       3.516533  22.604673  30.606900
# 2   38.189007        40.655895       3.516434  40.656520  41.657887
# 3   49.604940        51.705930       3.518496  51.706610  52.708897
# 4   57.604847        59.757782       3.519337  59.758415  62.760480
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 55

# %%
csv_path55 = r'sourcedata\UGDG\logs\3212\sub-3212_task-ultimatum_run-0_raw.csv '
df_SUB3212ULTIMATUM = pd.read_csv(csv_path55)#קובץ של מבחן אולטימטום של נבדק חמישים וחמש, ייצוג של דאטה פריים 
df_SUB3212ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3212ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3212\sub-3212_task-ultimatum_run-0_raw.csv')
#df_SUB3212ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים וחמש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      1         15    5  1.5         1         7  1.0
# 1            2       2      3         23    3  1.5         1         0  1.0
# 2            3       3      3         21    1  1.5         9         0  1.0
# 3            4       4      3         17    3  1.5         0         1  1.0
# 4            5       5      1         19    5  3.0         4         1  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.019003    7.535876        7.536017   2.0  1.033459
# 1    1.0  ...  18.068615   19.584887       19.585026   3.0  1.100780
# 2    2.0  ...  28.118540   29.634954       29.635100   2.0  1.200993
# 3    3.0  ...  36.168915   37.684933       37.685074   2.0  1.633738
# 4    4.0  ...  46.218940   49.235040       49.235150   2.0  0.900714
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.569477        11.052662       3.517270  11.053412  16.054930
# 1   20.685804        23.101065       3.516602  23.101728  26.102955
# 2   30.836092        33.152065       3.517497  33.152706  34.153572
# 3   39.318813        41.202090       3.517557  41.202732  44.204540
# 4   50.135864        52.751590       3.516977  52.752228  57.754288
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 56

# %%
csv_path56 = r'sourcedata\UGDG\logs\3218\sub-3218_task-ultimatum_run-0_raw.csv '
df_SUB3218ULTIMATUM = pd.read_csv(csv_path56)#קובץ של מבחן אולטימטום של נבדק חמישים ושש, ייצוג של דאטה פריים 
df_SUB3218ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3218ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3218\sub-3218_task-ultimatum_run-0_raw.csv ')
#df_SUB3218ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים ושש, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      3         25    1  1.5         5         0  1.0
# 1            2       2      2         25    1  1.5        11         2  1.0
# 2            3       3      1         25    1  1.5         2         8  1.0
# 3            4       4      3         25    3  3.0         0        11  1.0
# 4            5       5      1         23    3  1.5         7         4  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.006940    7.523547        7.523725   2.0  1.183142
# 1    1.0  ...  14.056333   15.574026       15.574145   2.0  1.882960
# 2    2.0  ...  22.105865   23.622910       23.623024   3.0  1.000153
# 3    3.0  ...  30.156141   33.174080       33.174232   3.0  2.049108
# 4    4.0  ...  41.705730   43.222164       43.222280   2.0  1.251158
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    8.706867        11.040043       3.516976  11.040850  12.042665
# 1   17.457106        19.091093       3.517485  19.091753  20.093927
# 2   24.623177        27.139030       3.516544  27.139690  28.140778
# 3   35.223340        36.690040       3.516368  36.690723  39.691692
# 4   44.473440        46.737965       3.516298  46.738700  49.740036
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 57

# %%
csv_path57 = r'sourcedata\UGDG\logs\3220\sub-3220_task-ultimatum_run-0_raw.csv '
df_SUB3220ULTIMATUM = pd.read_csv(csv_path57)#קובץ של מבחן אולטימטום של נבדק חמישים ושבע, ייצוג של דאטה פריים 
df_SUB3220ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3220ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3220\sub-3220_task-ultimatum_run-0_raw.csv')
#df_SUB3220ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים ושבע, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         21    1  4.5         4         9  1.0
# 1            2       2      1         17    1  1.5         1         5  1.0
# 2            3       3      2         21    1  1.5         7         1  1.0
# 3            4       4      3         25    1  3.0         8         0  1.0
# 4            5       5      3         17    1  3.0         1         0  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.004883   10.522058       10.522203   3.0  1.300065
# 1    1.0  ...  17.055014   18.572784       18.572908   3.0  1.432707
# 2    2.0  ...  25.105053   26.622057       26.622173   2.0  2.200294
# 3    3.0  ...  33.154987   36.172276       36.172420   2.0  1.450049
# 4    4.0  ...  42.704613   45.721043       45.721190   3.0  1.066981
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0   11.822268        14.038245       3.516689  14.039019  15.040881
# 1   20.005615        22.090014       3.517668  22.090687  23.092720
# 2   28.822466        30.138460       3.516826  30.139120  31.141060
# 3   37.622470        39.687927       3.516076  39.688618  40.690500
# 4   46.788174        49.239050       3.518403  49.239704  50.242165
#
# [5 rows x 23 columns]

# %% [markdown]
# # נבדק 58

# %%
csv_path58 = r'sourcedata\UGDG\logs\3223\sub-3223_task-ultimatum_run-0_raw.csv '
df_SUB3223ULTIMATUM = pd.read_csv(csv_path58)#קובץ של מבחן אולטימטום של נבדק חמישים ושמונה, ייצוג של דאטה פריים 
df_SUB3223ULTIMATUM.head() #רק 5 שורות ראשונות 

#df_SUB3223ULTIMATUM=pd.read_csv(r'C:\Users\jacky\Documents\projects\FINAL_PROJECT\sourcedata\UGDG\logs\3223\sub-3223_task-ultimatum_run-0_raw.csv')
#df_SUB3223ULTIMATUM #קובץ של מבחן אולטימטום של נבדק חמישים ושמונה, ייצוג של דאטה פריים
# Out:
#    TrialNumber  nTrial  Block  Endowment  ITI  ISI  L_Option  R_Option  ran  \
# 0            1       1      2         17    1  1.5         5         8  1.0
# 1            2       2      2         15    1  3.0         7         3  1.0
# 2            3       3      1         19    1  1.5         1         6  1.0
# 3            4       4      2         15    1  1.5         7         5  1.0
# 4            5       5      3         17    1  1.5         0         5  1.0
#
#    order  ...  ISI_onset  ISI_offset  decision_onset  resp        rt  \
# 0    0.0  ...   6.016926    7.534992        7.535137   3.0  1.833178
# 1    1.0  ...  14.067344   17.085001       17.085115   3.0  0.999928
# 2    2.0  ...  23.616909   25.135017       25.135134   3.0  1.165466
# 3    3.0  ...  31.667343   33.184420       33.184536   3.0  1.133777
# 4    4.0  ...  39.716785   41.234116       41.234264   2.0  2.933888
#
#    resp_onset  decision_offset  trialDuration   ITIonset  ITIoffset
# 0    9.368315        11.052012       3.517511  11.052777  12.055010
# 1   18.085045        20.601435       3.516933  20.602173  21.602997
# 2   26.300600        28.652933       3.518325  28.653574  29.656029
# 3   34.318314        36.701187       3.517175  36.701820  37.704014
# 4   44.168150        44.752010       3.518272  44.752655  45.755020
#
# [5 rows x 23 columns]

# %% [markdown]
# # איחוד טבלעות

# %%
from functools import reduce

# %%
dfs = [
    df_SUB102ULTIMATUM, df_SUB3125ULTIMATUM, df_SUB3122ULTIMATUM, df_SUB3116ULTIMATUM,
    df_SUB3101ULTIMATUM, df_SUB1303ULTIMATUM, df_SUB1302ULTIMATUM, df_SUB1301ULTIMATUM,
    df_SUB1300ULTIMATUM, df_SUB1294ULTIMATUM, df_SUB1286ULTIMATUM, df_SUB1282ULTIMATUM,
    df_SUB1276ULTIMATUM, df_SUB1255ULTIMATUM, df_SUB1253ULTIMATUM, df_SUB1251ULTIMATUM,
    df_SUB1249ULTIMATUM, df_SUB1248ULTIMATUM, df_SUB1247ULTIMATUM, df_SUB1245ULTIMATUM,
    df_SUB1244ULTIMATUM, df_SUB1243ULTIMATUM, df_SUB1242ULTIMATUM, df_SUB103ULTIMATUM,
    df_SUB104ULTIMATUM, df_SUB106ULTIMATUM, df_SUB107ULTIMATUM, df_SUB109ULTIMATUM,
    df_SUB110ULTIMATUM, df_SUB111ULTIMATUM, df_SUB112ULTIMATUM, df_SUB113ULTIMATUM,
    df_SUB115ULTIMATUM, df_SUB116ULTIMATUM, df_SUB119ULTIMATUM, df_SUB1021ULTIMATUM,
    df_SUB1240ULTIMATUM, df_SUB3140ULTIMATUM, df_SUB3143ULTIMATUM, df_SUB3152ULTIMATUM, df_SUB3164ULTIMATUM,df_SUB3166ULTIMATUM,
    df_SUB3167ULTIMATUM, df_SUB3170ULTIMATUM, df_SUB3173ULTIMATUM, df_SUB3175ULTIMATUM, df_SUB3176ULTIMATUM, 
    df_SUB3186ULTIMATUM, df_SUB3189ULTIMATUM, df_SUB3190ULTIMATUM, df_SUB3199ULTIMATUM, df_SUB3200ULTIMATUM, 
    df_SUB3206ULTIMATUM, df_SUB3210ULTIMATUM, df_SUB3212ULTIMATUM, df_SUB3218ULTIMATUM, df_SUB3220ULTIMATUM, df_SUB3223ULTIMATUM
]
merged_df = pd.concat(dfs, ignore_index=True)
merged_df
# Out:
#       ?TrialNumber Block Endowment ITI  ISI  cue_Onset endowment_onset  \
# 0              1.0     2        15   8  1.5    4.99026        5.990426
# 1              2.0     3        25   3  1.5  20.036234       21.035868
# 2              3.0     2        21   5  3.0  30.077942       31.077686
# 3              4.0     1        15   1  3.0  43.622337        44.62225
# 4              5.0     1        17   5  1.5  53.163296       54.163292
# ...            ...   ...       ...  ..  ...        ...             ...
# 2120           NaN     1        15   3  1.5   338.5519       339.55005
# 2121           NaN     1        21   1  3.0  348.60153           349.6
# 2122           NaN     1        15   3  4.5  358.15158          359.15
# 2123           NaN     3        25   1  1.5  371.20157        372.1997
# 2124           NaN     3        23   1  3.0  379.25174       380.24997
#
#      endowment_offset  ISI_onset ISI_offset  ...   ITIonset  ITIoffset  \
# 0            6.007139   6.007393   7.523706  ...  11.043097  19.047167
# 1           21.052696  21.052837  22.569616  ...  26.087952   29.09276
# 2           31.094276  31.094488   34.11137  ...    37.6298  42.633324
# 3           44.638508  44.638702  47.655624  ...   51.17301  52.177235
# 4             54.1797   54.17989  55.697296  ...  59.214474   64.21824
# ...               ...        ...        ...  ...        ...        ...
# 2120        339.56677    339.567  341.08414  ...   344.6005   347.6013
# 2121         349.6167  349.61688  352.63403  ...  356.15268  357.15472
# 2122        359.16653  359.16675   363.6843  ...   367.2017  370.20407
# 2123         372.2163  372.21637  373.73404  ...  377.25272  378.25494
# 2124         380.2665  380.26663  383.28412  ...  386.81854  387.82004
#
#      decision_time_range endowment_time_range TrialNumber nTrial L_Option  \
# 0               3.518582             0.016713         NaN    NaN      NaN
# 1               3.517667             0.016828         NaN    NaN      NaN
# 2               3.517814             0.016590         NaN    NaN      NaN
# 3               3.516667             0.016258         NaN    NaN      NaN
# 4               3.516550             0.016408         NaN    NaN      NaN
# ...                  ...                  ...         ...    ...      ...
# 2120                 NaN                  NaN          32     32        3
# 2121                 NaN                  NaN          33     33        7
# 2122                 NaN                  NaN          34     34        7
# 2123                 NaN                  NaN          35     35       11
# 2124                 NaN                  NaN          36     36        0
#
#      R_Option  ran  order
# 0         NaN  NaN    NaN
# 1         NaN  NaN    NaN
# 2         NaN  NaN    NaN
# 3         NaN  NaN    NaN
# 4         NaN  NaN    NaN
# ...       ...  ...    ...
# 2120        1  1.0   31.0
# 2121        9  1.0   32.0
# 2122        1  1.0   33.0
# 2123        0  1.0   34.0
# 2124        7  1.0   35.0
#
# [2125 rows x 26 columns]

# %%
merged_df.info()
merged_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2125 entries, 0 to 2124
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ?TrialNumber          36 non-null     float64
#  1   Block                 2125 non-null   object
#  2   Endowment             2125 non-null   object
#  3   ITI                   2125 non-null   object
#  4   ISI                   2125 non-null   object
#  5   cue_Onset             2125 non-null   object
#  6   endowment_onset       2125 non-null   object
#  7   endowment_offset      2125 non-null   object
#  8   ISI_onset             2125 non-null   object
#  9   ISI_offset            2125 non-null   object
#  10  decision_onset        2125 non-null   object
#  11  resp                  2125 non-null   object
#  12  rt                    2125 non-null   object
#  13  resp_onset            2125 non-null   object
#  14  decision_offset       2125 non-null   object
#  15  trialDuration         2125 non-null   object
#  16  ITIonset              2125 non-null   object
#  17  ITIoffset             2125 non-null   object
#  18  decision_time_range   72 non-null     float64
#  19  endowment_time_range  72 non-null     float64
#  20  TrialNumber           2089 non-null   object
#  21  nTrial                2053 non-null   object
#  22  L_Option              2053 non-null   object
#  23  R_Option              2053 non-null   object
#  24  ran                   2053 non-null   object
#  25  order                 2053 non-null   object
# dtypes: float64(3), object(23)
# memory usage: 431.8+ KB
#        ?TrialNumber  decision_time_range  endowment_time_range
# count     36.000000            72.000000             72.000000
# mean      18.500000             3.488511              0.016674
# std       10.535654             0.118165              0.000283
# min        1.000000             3.003570              0.015948
# 25%        9.750000             3.516643              0.016480
# 50%       18.500000             3.516835              0.016685
# 75%       27.250000             3.517232              0.016830
# max       36.000000             3.518582              0.017450

# %%
merged_df.isnull().sum() #כאן לא ביצענו ניקוי של desision time range וendowment rage .כי זה פר נבדק, בהמשך חישבנו את המשתנים הרלוונטים בבין נבדקי
# Out:
# ?TrialNumber            2089
# Block                      0
# Endowment                  0
# ITI                        0
# ISI                        0
# cue_Onset                  0
# endowment_onset            0
# endowment_offset           0
# ISI_onset                  0
# ISI_offset                 0
# decision_onset             0
# resp                       0
# rt                         0
# resp_onset                 0
# decision_offset            0
# trialDuration              0
# ITIonset                   0
# ITIoffset                  0
# decision_time_range     2053
# endowment_time_range    2053
# TrialNumber               36
# nTrial                    72
# L_Option                  72
# R_Option                  72
# ran                       72
# order                     72
# dtype: int64

# %%
print(merged_df.columns)
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset', 'decision_time_range',
#        'endowment_time_range', 'TrialNumber', 'nTrial', 'L_Option', 'R_Option',
#        'ran', 'order'],
#       dtype='object')

# %%
merged_df.drop(['ran', 'nTrial', 'L_Option','L_Option', 'order'], axis=1, inplace=True)
print(merged_df.columns)
merged_df.head()
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset', 'decision_time_range',
#        'endowment_time_range', 'TrialNumber', 'R_Option'],
#       dtype='object')
#    ?TrialNumber Block Endowment ITI  ISI  cue_Onset endowment_onset  \
# 0           1.0     2        15   8  1.5    4.99026        5.990426
# 1           2.0     3        25   3  1.5  20.036234       21.035868
# 2           3.0     2        21   5  3.0  30.077942       31.077686
# 3           4.0     1        15   1  3.0  43.622337        44.62225
# 4           5.0     1        17   5  1.5  53.163296       54.163292
#
#   endowment_offset  ISI_onset ISI_offset  ...        rt resp_onset  \
# 0         6.007139   6.007393   7.523706  ...  1.735912   9.259807
# 1        21.052696  21.052837  22.569616  ...  1.835817  24.405628
# 2        31.094276  31.094488   34.11137  ...  1.703661   35.81518
# 3        44.638508  44.638702  47.655624  ...  1.520435   49.17621
# 4          54.1797   54.17989  55.697296  ...  1.268358  56.965805
#
#   decision_offset trialDuration   ITIonset  ITIoffset decision_time_range  \
# 0       11.042476      3.519057  11.043097  19.047167            3.518582
# 1       26.087477      3.518021  26.087952   29.09276            3.517667
# 2       37.629337      3.518159    37.6298  42.633324            3.517814
# 3        51.17244      3.517102   51.17301  52.177235            3.516667
# 4          59.214      3.516906  59.214474   64.21824            3.516550
#
#   endowment_time_range  TrialNumber  R_Option
# 0             0.016713          NaN       NaN
# 1             0.016828          NaN       NaN
# 2             0.016590          NaN       NaN
# 3             0.016258          NaN       NaN
# 4             0.016408          NaN       NaN
#
# [5 rows x 22 columns]

# %%
merged_df.iloc[0:2125, [merged_df.columns.get_loc('decision_onset'), merged_df.columns.get_loc('decision_offset')]]
# Out:
#      decision_onset decision_offset
# 0          7.523894       11.042476
# 1          22.56981       26.087477
# 2         34.111523       37.629337
# 3         47.655773        51.17244
# 4          55.69745          59.214
# ...             ...             ...
# 2120      341.08426       344.59982
# 2121      352.63416       356.15204
# 2122      363.68442       367.20105
# 2123       373.7342       377.25208
# 2124      383.28424       386.30002
#
# [2125 rows x 2 columns]

# %%
indexfordecision=merged_df.set_index(['decision_onset', 'decision_offset']) #המרת עמודות לאינדקסים

# %%
print(merged_df.columns)
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset', 'decision_time_range',
#        'endowment_time_range', 'TrialNumber', 'R_Option'],
#       dtype='object')

# %%
indexfordecision=merged_df.set_index(['decision_onset', 'decision_offset'])
indexfordecision.head()
# Out:
#                                 ?TrialNumber Block Endowment ITI  ISI  \
# decision_onset decision_offset
# 7.523894       11.042476                 1.0     2        15   8  1.5
# 22.56981       26.087477                 2.0     3        25   3  1.5
# 34.111523      37.629337                 3.0     2        21   5  3.0
# 47.655773      51.17244                  4.0     1        15   1  3.0
# 55.69745       59.214                    5.0     1        17   5  1.5
#
#                                 cue_Onset endowment_onset endowment_offset  \
# decision_onset decision_offset
# 7.523894       11.042476          4.99026        5.990426         6.007139
# 22.56981       26.087477        20.036234       21.035868        21.052696
# 34.111523      37.629337        30.077942       31.077686        31.094276
# 47.655773      51.17244         43.622337        44.62225        44.638508
# 55.69745       59.214           53.163296       54.163292          54.1797
#
#                                 ISI_onset ISI_offset resp        rt  \
# decision_onset decision_offset
# 7.523894       11.042476         6.007393   7.523706    3  1.735912
# 22.56981       26.087477        21.052837  22.569616    2  1.835817
# 34.111523      37.629337        31.094488   34.11137    3  1.703661
# 47.655773      51.17244         44.638702  47.655624    2  1.520435
# 55.69745       59.214            54.17989  55.697296    3  1.268358
#
#                                resp_onset trialDuration   ITIonset  ITIoffset  \
# decision_onset decision_offset
# 7.523894       11.042476         9.259807      3.519057  11.043097  19.047167
# 22.56981       26.087477        24.405628      3.518021  26.087952   29.09276
# 34.111523      37.629337         35.81518      3.518159    37.6298  42.633324
# 47.655773      51.17244          49.17621      3.517102   51.17301  52.177235
# 55.69745       59.214           56.965805      3.516906  59.214474   64.21824
#
#                                 decision_time_range  endowment_time_range  \
# decision_onset decision_offset
# 7.523894       11.042476                   3.518582              0.016713
# 22.56981       26.087477                   3.517667              0.016828
# 34.111523      37.629337                   3.517814              0.016590
# 47.655773      51.17244                    3.516667              0.016258
# 55.69745       59.214                      3.516550              0.016408
#
#                                TrialNumber R_Option
# decision_onset decision_offset
# 7.523894       11.042476               NaN      NaN
# 22.56981       26.087477               NaN      NaN
# 34.111523      37.629337               NaN      NaN
# 47.655773      51.17244                NaN      NaN
# 55.69745       59.214                  NaN      NaN

# %%
merged_df['decision_offset'] = pd.to_numeric(merged_df['decision_offset'], errors='coerce') #המרה למשתנה מספרי
merged_df['decision_onset'] = pd.to_numeric(merged_df['decision_onset'], errors='coerce')

merged_df['decision_time_range_for_all'] = merged_df['decision_offset'] - merged_df['decision_onset']#חישוב טווח ויצירת משתנה חדש 
merged_df.iloc[0:2125, [merged_df.columns.get_loc('decision_time_range_for_all')]] #יצוג של התוצאה בתור משתנה חדש
# Out:
#       decision_time_range_for_all
# 0                        3.518582
# 1                        3.517667
# 2                        3.517814
# 3                        3.516667
# 4                        3.516550
# ...                           ...
# 2120                     3.515560
# 2121                     3.517880
# 2122                     3.516630
# 2123                     3.517880
# 2124                     3.015780
#
# [2125 rows x 1 columns]

# %%
merged_df.iloc[0:2125, [merged_df.columns.get_loc('endowment_onset'), merged_df.columns.get_loc('endowment_offset')]] #ייצוג משתנה תמורה
# Out:
#      endowment_onset endowment_offset
# 0           5.990426         6.007139
# 1          21.035868        21.052696
# 2          31.077686        31.094276
# 3           44.62225        44.638508
# 4          54.163292          54.1797
# ...              ...              ...
# 2120       339.55005        339.56677
# 2121           349.6         349.6167
# 2122          359.15        359.16653
# 2123        372.1997         372.2163
# 2124       380.24997         380.2665
#
# [2125 rows x 2 columns]

# %%
indexfordecision=merged_df.set_index(['endowment_onset', 'endowment_offset']) #המרת עמודות לאינדקסים
indexfordecision.head()
# Out:
#                                   ?TrialNumber Block Endowment ITI  ISI  \
# endowment_onset endowment_offset
# 5.990426        6.007139                   1.0     2        15   8  1.5
# 21.035868       21.052696                  2.0     3        25   3  1.5
# 31.077686       31.094276                  3.0     2        21   5  3.0
# 44.62225        44.638508                  4.0     1        15   1  3.0
# 54.163292       54.1797                    5.0     1        17   5  1.5
#
#                                   cue_Onset  ISI_onset ISI_offset  \
# endowment_onset endowment_offset
# 5.990426        6.007139            4.99026   6.007393   7.523706
# 21.035868       21.052696         20.036234  21.052837  22.569616
# 31.077686       31.094276         30.077942  31.094488   34.11137
# 44.62225        44.638508         43.622337  44.638702  47.655624
# 54.163292       54.1797           53.163296   54.17989  55.697296
#
#                                   decision_onset resp  ... resp_onset  \
# endowment_onset endowment_offset                       ...
# 5.990426        6.007139                7.523894    3  ...   9.259807
# 21.035868       21.052696              22.569810    2  ...  24.405628
# 31.077686       31.094276              34.111523    3  ...   35.81518
# 44.62225        44.638508              47.655773    2  ...   49.17621
# 54.163292       54.1797                55.697450    3  ...  56.965805
#
#                                  decision_offset  trialDuration   ITIonset  \
# endowment_onset endowment_offset
# 5.990426        6.007139               11.042476       3.519057  11.043097
# 21.035868       21.052696              26.087477       3.518021  26.087952
# 31.077686       31.094276              37.629337       3.518159    37.6298
# 44.62225        44.638508              51.172440       3.517102   51.17301
# 54.163292       54.1797                59.214000       3.516906  59.214474
#
#                                   ITIoffset decision_time_range  \
# endowment_onset endowment_offset
# 5.990426        6.007139          19.047167            3.518582
# 21.035868       21.052696          29.09276            3.517667
# 31.077686       31.094276         42.633324            3.517814
# 44.62225        44.638508         52.177235            3.516667
# 54.163292       54.1797            64.21824            3.516550
#
#                                   endowment_time_range  TrialNumber R_Option  \
# endowment_onset endowment_offset
# 5.990426        6.007139                      0.016713          NaN      NaN
# 21.035868       21.052696                     0.016828          NaN      NaN
# 31.077686       31.094276                     0.016590          NaN      NaN
# 44.62225        44.638508                     0.016258          NaN      NaN
# 54.163292       54.1797                       0.016408          NaN      NaN
#
#                                  decision_time_range_for_all
# endowment_onset endowment_offset
# 5.990426        6.007139                            3.518582
# 21.035868       21.052696                           3.517667
# 31.077686       31.094276                           3.517814
# 44.62225        44.638508                           3.516667
# 54.163292       54.1797                             3.516550
#
# [5 rows x 21 columns]

# %%
merged_df['endowment_offset'] = pd.to_numeric(merged_df['endowment_offset'], errors='coerce') #המרה למשתנה מספרי
merged_df['endowment_onset'] = pd.to_numeric(merged_df['endowment_onset'], errors='coerce')

merged_df['endowment_time_range_for_all'] = merged_df['endowment_offset'] - merged_df['endowment_onset']#חישוב טווח ויצירת משתנה חדש 
merged_df.iloc[0:2125, [merged_df.columns.get_loc('endowment_time_range_for_all')]] #יצוג של התוצאה בתור משתנה חדש
# Out:
#       endowment_time_range_for_all
# 0                         0.016713
# 1                         0.016828
# 2                         0.016590
# 3                         0.016258
# 4                         0.016408
# ...                            ...
# 2120                      0.016720
# 2121                      0.016700
# 2122                      0.016530
# 2123                      0.016600
# 2124                      0.016530
#
# [2125 rows x 1 columns]

# %%
print(merged_df.columns) #בדיקה שנוצרו 2 עמודות חדשות
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset', 'decision_time_range',
#        'endowment_time_range', 'TrialNumber', 'R_Option',
#        'decision_time_range_for_all', 'endowment_time_range_for_all'],
#       dtype='object')

# %%
merged_df['resp_onset'] = pd.to_numeric(merged_df['resp_onset'], errors='coerce') #המרה למשתנה מספרי

# %%
mean_decision_time_range_for_all=merged_df['decision_time_range_for_all'].mean() #בין נבדקי - ממוצע של זמן ההחלטה 
print(f"הממוצע של זמן ההחלטה עבור כל הנבדקים הוא: {mean_decision_time_range_for_all}")
mean_endowment_time_range_for_all=merged_df['endowment_time_range_for_all'].mean() #ממוצע של מצב תרומה - בין נבדקי
print(f"הממוצע של מצב התרומה עבור כל הנבדקים הוא: {mean_endowment_time_range_for_all}")
mean_resp_onset_for_all=merged_df['resp_onset'].mean() #ממוצע של תחילת זמן תגובה - בין נבדקי
print(f"הממוצע של תחילת זמן תגובה עבור כל הנבדקים הוא: {mean_resp_onset_for_all}")

std_decision_time_range_for_all = merged_df['decision_time_range_for_all'].std() #סטיית תקן של זמן ההחלטה 
print(f"סטיית תקן של זמן ההחלטה הוא:{std_decision_time_range_for_all}")
std_endowment_time_range_for_all = merged_df['endowment_time_range_for_all'].std() #סטיית תקן של זמן מצב תרומה 
print(f"סטיית תקן של זמן תרומה הוא:{std_endowment_time_range_for_all}")
std_resp_onset_for_all = merged_df['resp_onset'].std() #סטיית תקן של זמן תגובה  
print(f"סטיית תקן של זמן תגובה הוא:{std_resp_onset_for_all}")
# Out:
# הממוצע של זמן ההחלטה עבור כל הנבדקים הוא: 3.5049736460937506
# הממוצע של מצב התרומה עבור כל הנבדקים הוא: 0.03360931404193048
# הממוצע של תחילת זמן תגובה עבור כל הנבדקים הוא: 213.68637020947264
# סטיית תקן של זמן ההחלטה הוא:0.07679295986775637
# סטיית תקן של זמן תרומה הוא:0.12847699763363438
# סטיית תקן של זמן תגובה הוא:163.74835803729655

# %%
import numpy as np
mean_values = [mean_decision_time_range_for_all, mean_endowment_time_range_for_all, mean_resp_onset_for_all] #תיאור נתונים עבורם מייצרת את הגרף
std_values = [std_decision_time_range_for_all, std_endowment_time_range_for_all, std_resp_onset_for_all]
labels = ['Decision Time', 'Endowment Time', 'Response Onset'] 

x = np.arange(len(labels))  # יצירת גרף
fig, ax = plt.subplots(figsize=(10, 8)) #עמודות עבור ממוצעים
ax.bar(x, mean_values, yerr=std_values, capsize=5, color='skyblue', edgecolor='black')

ax.set_ylabel('Time (seconds)') #תוויות
ax.set_title('Mean Values with Standard Deviations')
ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.tight_layout() #הצגה של הגרף 
plt.show()

# %%
merged_df_selected = merged_df[['decision_time_range_for_all', 'endowment_time_range_for_all', 'resp_onset']] #בחירת 3 משתנים לחישוב קורלציה 
correlation_matrix_for_all = merged_df_selected.corr() #חישוב קשר בין המשתנים 
correlation_matrix_for_all
# Out:
#                               decision_time_range_for_all  \
# decision_time_range_for_all                      1.000000
# endowment_time_range_for_all                    -0.162749
# resp_onset                                      -0.743065
#
#                               endowment_time_range_for_all  resp_onset
# decision_time_range_for_all                      -0.162749   -0.743065
# endowment_time_range_for_all                      1.000000    0.051750
# resp_onset                                        0.051750    1.000000

# %%
import seaborn as sns 
sns.scatterplot(x='decision_time_range_for_all', y='endowment_time_range_for_all', hue='resp_onset', data=merged_df) #גרף קשר בין שלושת המשתנים
sns.regplot(x='decision_time_range_for_all', y='endowment_time_range_for_all', scatter=False, data=merged_df, line_kws={"color": "red"}) 
sns.regplot(x='resp_onset', y='decision_time_range_for_all', scatter=False, data=merged_df, line_kws={"color": "orange"}) 
sns.regplot(x='resp_onset', y='endowment_time_range_for_all', scatter=False, data=merged_df, line_kws={"color": "blue"}) 
plt.show()

# %%
sns.scatterplot(x='decision_time_range_for_all', y='endowment_time_range_for_all', data=merged_df) #גרף קשר בין משתנה זמן ההחלטה וזמן תרומה המשתנים
sns.regplot(x='decision_time_range_for_all', y='endowment_time_range_for_all', data=merged_df, scatter=False, line_kws={'color': 'red'})
plt.show()

# %%
sns.scatterplot(x='resp_onset', y='decision_time_range_for_all', data=merged_df) #גרף קשר בין זמן תגובה לזמן ההחלטה המשתנים
sns.regplot(x='resp_onset', y='decision_time_range_for_all', data=merged_df, scatter=False, line_kws={'color': 'red'})
plt.show()

# %%
sns.scatterplot(x='resp_onset', y='endowment_time_range_for_all', data=merged_df) #גרף קשר בין זמן תגובה לזמן תרומה המשתנים
sns.regplot(x='resp_onset', y='endowment_time_range_for_all', data=merged_df, scatter=False, line_kws={'color': 'red'})
plt.show()

# %% [markdown]
# # חלוקה של משתנים רלוונטים בלבד

# %%
# יצירת שני משתנים חדשים בעמודות:
merged_df['social_reward'] = merged_df['endowment_time_range_for_all'].apply(lambda x: x if x < mean_endowment_time_range_for_all  else None) #תגובה בתרומה מהירה מאוד - תגמול חברתי
merged_df['financial_reward'] = merged_df['endowment_time_range_for_all'].apply(lambda x: x if x > mean_endowment_time_range_for_all  else None) #תגובה במרומה איטית מאוד - תגמול כלכלי
merged_df# הצגת התוצאות
# Out:
#       ?TrialNumber Block Endowment ITI  ISI  cue_Onset  endowment_onset  \
# 0              1.0     2        15   8  1.5    4.99026         5.990426
# 1              2.0     3        25   3  1.5  20.036234        21.035868
# 2              3.0     2        21   5  3.0  30.077942        31.077686
# 3              4.0     1        15   1  3.0  43.622337        44.622250
# 4              5.0     1        17   5  1.5  53.163296        54.163292
# ...            ...   ...       ...  ..  ...        ...              ...
# 2120           NaN     1        15   3  1.5   338.5519       339.550050
# 2121           NaN     1        21   1  3.0  348.60153       349.600000
# 2122           NaN     1        15   3  4.5  358.15158       359.150000
# 2123           NaN     3        25   1  1.5  371.20157       372.199700
# 2124           NaN     3        23   1  3.0  379.25174       380.249970
#
#       endowment_offset  ISI_onset ISI_offset  ...   ITIonset  ITIoffset  \
# 0             6.007139   6.007393   7.523706  ...  11.043097  19.047167
# 1            21.052696  21.052837  22.569616  ...  26.087952   29.09276
# 2            31.094276  31.094488   34.11137  ...    37.6298  42.633324
# 3            44.638508  44.638702  47.655624  ...   51.17301  52.177235
# 4            54.179700   54.17989  55.697296  ...  59.214474   64.21824
# ...                ...        ...        ...  ...        ...        ...
# 2120        339.566770    339.567  341.08414  ...   344.6005   347.6013
# 2121        349.616700  349.61688  352.63403  ...  356.15268  357.15472
# 2122        359.166530  359.16675   363.6843  ...   367.2017  370.20407
# 2123        372.216300  372.21637  373.73404  ...  377.25272  378.25494
# 2124        380.266500  380.26663  383.28412  ...  386.81854  387.82004
#
#      decision_time_range  endowment_time_range  TrialNumber R_Option  \
# 0               3.518582              0.016713          NaN      NaN
# 1               3.517667              0.016828          NaN      NaN
# 2               3.517814              0.016590          NaN      NaN
# 3               3.516667              0.016258          NaN      NaN
# 4               3.516550              0.016408          NaN      NaN
# ...                  ...                   ...          ...      ...
# 2120                 NaN                   NaN           32        1
# 2121                 NaN                   NaN           33        9
# 2122                 NaN                   NaN           34        1
# 2123                 NaN                   NaN           35        0
# 2124                 NaN                   NaN           36        7
#
#      decision_time_range_for_all endowment_time_range_for_all  social_reward  \
# 0                       3.518582                     0.016713       0.016713
# 1                       3.517667                     0.016828       0.016828
# 2                       3.517814                     0.016590       0.016590
# 3                       3.516667                     0.016258       0.016258
# 4                       3.516550                     0.016408       0.016408
# ...                          ...                          ...            ...
# 2120                    3.515560                     0.016720       0.016720
# 2121                    3.517880                     0.016700       0.016700
# 2122                    3.516630                     0.016530       0.016530
# 2123                    3.517880                     0.016600       0.016600
# 2124                    3.015780                     0.016530       0.016530
#
#       financial_reward
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2120               NaN
# 2121               NaN
# 2122               NaN
# 2123               NaN
# 2124               NaN
#
# [2125 rows x 26 columns]

# %%
print(merged_df.columns) #בדיקה האם נוצרות עמודות חדשות
# Out:
# Index(['?TrialNumber', 'Block', 'Endowment', 'ITI', 'ISI', 'cue_Onset',
#        'endowment_onset', 'endowment_offset', 'ISI_onset', 'ISI_offset',
#        'decision_onset', 'resp', 'rt', 'resp_onset', 'decision_offset',
#        'trialDuration', 'ITIonset', 'ITIoffset', 'decision_time_range',
#        'endowment_time_range', 'TrialNumber', 'R_Option',
#        'decision_time_range_for_all', 'endowment_time_range_for_all',
#        'social_reward', 'financial_reward'],
#       dtype='object')

# %%
merged_df.iloc[0:2125, [merged_df.columns.get_loc('social_reward'), merged_df.columns.get_loc('financial_reward')]]
# Out:
#       social_reward  financial_reward
# 0          0.016713               NaN
# 1          0.016828               NaN
# 2          0.016590               NaN
# 3          0.016258               NaN
# 4          0.016408               NaN
# ...             ...               ...
# 2120       0.016720               NaN
# 2121       0.016700               NaN
# 2122       0.016530               NaN
# 2123       0.016600               NaN
# 2124       0.016530               NaN
#
# [2125 rows x 2 columns]

# %%
merged_df['social_reward'].isnull().sum().sum() #Nan ייצוג של כמות
# Out:
# np.int64(109)

# %%
merged_df['financial_reward'].isnull().sum().sum() #Nan ייצוג של כמות
# Out:
# np.int64(2090)

# %%
max_value_social_reward = merged_df['social_reward'].max()
print(max_value_social_reward)
# Out:
# 0.022610000000042874

# %%
max_value_financial_reward = merged_df['financial_reward'].max()
print(max_value_financial_reward)
# Out:
# 1.0120038999999998

# %%
merged_df["social_reward"] = merged_df["social_reward"].fillna(merged_df["social_reward"].max()) #מילוי ערכים חסרים על ידי מקסימום 
merged_df["financial_reward"] = pd.to_numeric(merged_df["financial_reward"], errors='coerce')
merged_df["financial_reward"] = merged_df["financial_reward"].fillna(merged_df["financial_reward"].max()) # מילוי ערכים חסרים על ידי מקסימום

# %%
merged_df['social_reward'].isnull().sum().sum() # בדיקה שהמילוי עבד
# Out:
# np.int64(0)

# %%
merged_df.iloc[0:2125, [merged_df.columns.get_loc('social_reward'), merged_df.columns.get_loc('financial_reward')]]
# Out:
#       social_reward  financial_reward
# 0          0.016713          1.012004
# 1          0.016828          1.012004
# 2          0.016590          1.012004
# 3          0.016258          1.012004
# 4          0.016408          1.012004
# ...             ...               ...
# 2120       0.016720          1.012004
# 2121       0.016700          1.012004
# 2122       0.016530          1.012004
# 2123       0.016600          1.012004
# 2124       0.016530          1.012004
#
# [2125 rows x 2 columns]

# %%
mean_social_reward=merged_df['social_reward'].mean()
print(f"הממוצע של תגמול חברתי עבור כל הנבדקים הוא: {mean_social_reward}")
mean_financial_reward=merged_df['financial_reward'].mean() 
print(f"הממוצע של תגמול כלכלי עבור כל הנבדקים הוא: {mean_financial_reward}")

std_social_reward = merged_df['social_reward'].std() 
print(f"סטיית תקן של תגמול חברתי עבור כל הנבדקים הוא:{std_social_reward}")
std_financial_reward = merged_df['financial_reward'].std() 
print(f"סטיית תקן של תגמול כלכלי עבור כל הנבדקים  הוא:{std_financial_reward}")
# Out:
# הממוצע של תגמול חברתי עבור כל הנבדקים הוא: 0.01698906743529603
# הממוצע של תגמול כלכלי עבור כל הנבדקים הוא: 1.0119452121411763
# סטיית תקן של תגמול חברתי עבור כל הנבדקים הוא:0.0013303129730097374
# סטיית תקן של תגמול כלכלי עבור כל הנבדקים  הוא:0.00048389448197189383

# %%
import numpy as np
mean_values = [mean_social_reward*100, mean_financial_reward*100, mean_resp_onset_for_all] # הוכפל כדי לראות את גובהה העמודות ולהבחין טוב יותר כי הנתונים בשניות ,תיאור נתונים עבורם מייצרת את הגרף
std_values = [std_social_reward,std_financial_reward, std_resp_onset_for_all]
labels = ['Social_reward Time', 'Financial_reward Time', 'Response Onset'] 

x = np.arange(len(labels))  # יצירת גרף
fig, ax = plt.subplots(figsize=(10, 16)) #עמודות עבור ממוצעים
ax.bar(x, mean_values, yerr=std_values, capsize=5, color='skyblue', edgecolor='black')

ax.set_ylabel('Time (seconds)') #תוויות
ax.set_title('Mean Values with Standard Deviations')
ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.tight_layout() #הצגה של הגרף 
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# גרף התפלגות לתגמול חברתי
plt.figure(figsize=(10, 6))
sns.histplot(merged_df['social_reward'], kde=True, color='blue', bins=20, label='Social Reward')
plt.axvline(mean_social_reward, color='red', linestyle='--', label='mean of social reward')
plt.axvline(mean_social_reward + std_social_reward, color='green', linestyle='--', label='mean + std')
plt.axvline(mean_social_reward - std_social_reward, color='green', linestyle='--', label='std - mean')
plt.title('Social Reward')
plt.xlabel('Social Reward')
plt.ylabel('frequency')
plt.legend()
plt.show()
# גרף התפלגות לתגמול כלכלי
plt.figure(figsize=(10, 6))
sns.histplot(merged_df['financial_reward'], kde=True, color='orange', bins=20, label='Fanancial Reward')
plt.axvline(mean_financial_reward, color='red', linestyle='--', label='mean of Fanancial Reward')
plt.axvline(mean_financial_reward + std_financial_reward, color='green', linestyle='--', label='mean + std')
plt.axvline(mean_financial_reward - std_financial_reward, color='green', linestyle='--', label='mean - std')
plt.title('Fanancial Rewardי')
plt.xlabel('Fanancial Reward')
plt.ylabel('frequency')
plt.legend()
plt.show()

# %%
merged_df_selectedvarebles = merged_df[['social_reward', 'financial_reward', 'resp_onset']] #בחירת 3 משתנים לחישוב קורלציה 
correlation_varibales = merged_df_selectedvarebles.corr() #חישוב קשר בין המשתנים 
print(correlation_varibales)
# Out:
#                   social_reward  financial_reward  resp_onset
# social_reward          1.000000         -0.512692    0.057602
# financial_reward      -0.512692          1.000000    0.011920
# resp_onset             0.057602          0.011920    1.000000

# %%
sns.scatterplot(x='social_reward', y='financial_reward', hue='resp_onset', data=merged_df) #גרף קשר בין שלושת המשתנים
sns.regplot(x='social_reward', y='financial_reward', scatter=False, data=merged_df, line_kws={"color": "red"}) 
sns.regplot(x='resp_onset', y='financial_reward', scatter=False, data=merged_df, line_kws={"color": "orange"}) 
sns.regplot(x='resp_onset', y='social_reward', scatter=False, data=merged_df, line_kws={"color": "blue"}) 
plt.show()
